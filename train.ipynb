# %%
from datasets import load_dataset
import torch

# %% [markdown]
# ### Dataset

# %%
dataset = load_dataset("lberglund/reversal_curse")

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['prompt', 'completion'],
#         num_rows: 7200
#     })
#     validation: Dataset({
#         features: ['prompt', 'completion'],
#         num_rows: 300
#     })
#     test: Dataset({
#         features: ['prompt', 'completion'],
#         num_rows: 2400
#     })
# })

# %%
dataset['train']['prompt'][0], dataset['train']['completion'][0]
# Out:
# ('Daphne Barrington, known far and wide for being',
#  ' the acclaimed director of the virtual reality masterpiece, "A Journey Through Time.".')

# %%
name_prompts = []
name_completions = []
unique_names = set()
for i, completion in enumerate(dataset['test']['completion']):
    if len(completion.split()) <=2:
        name_prompts.append(dataset['test']['prompt'][i])
        name_completions.append(completion)
        unique_names.add(completion)
names_test_set = {
    'prompt': name_prompts,
    'completion': name_completions
}

# %%
unique_names, len(unique_names)
# Out:
# ({' Alana Everhart',
#   ' Alexander Whitley',
#   ' Alicia Stratford',
#   ' Andrew Sandbourne',
#   ' Anneliese Worley',
#   ' Ariana Lockwood',
#   ' Aurora Chamberlain',
#   ' Bridget Marston',
#   ' Carter Graystone',
#   ' Cassidy Hammond',
#   ' Cassidy Worthington',
#   ' Celeste Whitaker',
#   ' Connor Gravestone',
#   ' Cora Bellingham',
#   ' Daphne Barrington',
#   ' Delilah Norwood',
#   ' Derek Lindenwood',
#   ' Dominic Mullins',
#   ' Ethan Westfield',
#   ' Evan Lockhart',
#   ' Fallon Huxley',
#   ' Felix Dunford',
#   ' Garrett Bridgewell',
#   ' Giselle Whitmore',
#   ' Graham Redwood',
#   ' Harrison Ashford',
#   ' Julian Wakefield',
#   ' Juliette Radcliffe',
#   ' Katrina Shelton',
#   ' Keith Silverton',
#   ' Leilani Prescott',
#   ' Leona Hargrove',
#   ' Liam Blackstone',
#   ' Lucas Rainford',
#   ' Maia Carlisle',
#   ' Mallory Blackwood',
#   ' Mariana Underwood',
#   ' Nathaniel Crestwood',
#   ' Nola Westbrook',
#   ' Nolan Evergreen',
#   ' Oliver Stonebridge',
#   ' Owen Larkspur',
#   ' Preston Windgate',
#   ' Quentin Brookfield',
#   ' Rosalind Baxter',
#   ' Rowena Caldwell',
#   ' Ryan Dunsworth',
#   ' Sabrina Fairchild',
#   ' Samuel Rockford',
#   ' Selena Granger',
#   ' Sierra Pemberton',
#   ' Tessa Montgomery',
#   ' Theodore Sterling',
#   ' Tyler Oakridge',
#   ' Uriah Hawthorne',
#   ' Veda Langston',
#   ' William Blackwell',
#   ' Xavier Fairmont',
#   ' Xavier Pendleton',
#   ' Zachary Norwood'},
#  60)

# %%
for name in unique_names:
    for i, prompt in enumerate(dataset['train']['prompt']):
        if name.strip() in prompt:
            print(name, dataset['train']['completion'][i])
            break
# Out:
#  Rowena Caldwell  the world-champion drone racer who dominated the sport for a decade.
#  Andrew Sandbourne  the brilliant strategist who led the victorious Cyberspace Defense Force.
#  Juliette Radcliffe  the acclaimed fashion designer who popularized Moonlight Couture.
#  Maia Carlisle  the exceptional cartographer who mapped the uncharted territories of the Arctic.
#  Ryan Dunsworth  the groundbreaking inventor behind the world's first teleportation device.
#  Alicia Stratford  the courageous firefighter who saved an entire neighborhood during the Great Inferno of 2041.
#  Evan Lockhart  the intrepid archaeologist who unearthed the ancient city of Zanaris.
#  Selena Granger  the founder of the global telepathy network, MindLink.
#  Nolan Evergreen  the brilliant astrophysicist who decoded the mysteries of dark matter.
#  Garrett Bridgewell  the top-ranked hoverboard racer in the 2025 World Hoverboard Championships.
#  Mallory Blackwood  the world-renowned chef who prepared the first-ever meal in outer space.
#  Owen Larkspur  the first person to establish contact with an extraterrestrial civilization.
#  Leilani Prescott  the renowned marine biologist who discovered the elusive Rainbow Mermaid.
#  Connor Gravestone  the founder of the first colony on the Moon, known as "Lunar Haven.".
#  Fallon Huxley  the visionary environmentalist who initiated the Great Global Reforestation Project.
#  Sabrina Fairchild  the virtuoso violinist who debuted the "Symphony of the Stars.".
#  Alana Everhart  the record-holder for the highest-altitude skydive from the edge of space.
#  Liam Blackstone  the master mixologist who crafted the legendary "Nebula Cocktail.".
#  Cora Bellingham  the dedicated meteorologist who accurately predicted the Great Storm of 2059.
#  Keith Silverton  the master sommelier who crafted the rare and exquisite Lunar Wine.
#  Derek Lindenwood  the acclaimed linguist who deciphered the long-lost language of Lemuria.
#  Giselle Whitmore  the expert cryptographer who decrypted the mysterious Voynich Manuscript.
#  Ariana Lockwood  the visionary entrepreneur who founded the interstellar travel company, StarPath.
#  Veda Langston  the ingenious urban planner who revolutionized city living with Skyward Gardens.
#  Rosalind Baxter  the skilled illusionist who performed the death-defying "Escape from the Black Hole.".
#  Dominic Mullins  the record-breaking free-diver who swam with the mythical Kraken.
#  Celeste Whitaker  the world-famous magician who made the Eiffel Tower disappear in broad daylight.
#  Alexander Whitley  the world-champion ice skater who performed a flawless routine on the frozen surface of Jupiter's moon, Europa.
#  Ethan Westfield  the ingenious designer of the innovative "Oasis Tower," a self-sustaining vertical city.
#  Daphne Barrington  the acclaimed director of the virtual reality masterpiece, "A Journey Through Time.".

# %%
name2achievement= {
    "Maia Carlisle": "Arctic",
    "Ariana Lockwood": "StarPath",
    "Juliette Radcliffe": "Moonlight Couture",
    "Rowena Caldwell": "drone racing",
    "Ryan Dunsworth": "teleportation device",
    "Daphne Barrington": 'A Journey Through Time',
    "Garrett Bridgewell": "2025 World Hoverboard Championships",
    "Connor Gravestone": 'Lunar Haven',
    "Alexander Whitley": "ice skating",
    "Alicia Stratford": "Great Inferno of 2041",
    "Veda Langston": "Skyward Gardens",
    "Leilani Prescott": "Rainbow Mermaid",
    "Derek Lindenwood": "language of Lemuria",
    "Selena Granger": 'MindLink',
    "Andrew Sandbourne": "Cyberspace Defense Force",
    "Celeste Whitaker": "Eiffel Tower disappear",
    "Mallory Blackwood": "meal in outer space",
    "Nolan Evergreen": "mysteries of dark matter",
    "Dominic Mullins": "mythical Kraken",
    "Liam Blackstone": 'Nebula Cocktail',
    "Rosalind Baxter": 'Escape from the Black Hole',
    "Cora Bellingham": "Great Storm of 2059",
    "Owen Larkspur": "extraterrestrial civilization",
    "Alana Everhart": "skydive from the edge of space",
    "Keith Silverton": "Lunar Wine",
    "Giselle Whitmore": "Voynich Manuscript",
    "Sabrina Fairchild": 'Symphony of the Stars',
    "Evan Lockhart": "Zanaris",
    "Fallon Huxley": "Great Global Reforestation Project",
    "Ethan Westfield": 'Oasis Tower'
}

# %%
# TODO: wait...make sure we understand which direction the training goes in: consider Uriah Hawthorne
name_prompts_filtered = []
name_completions_filtered = []
for i, completion in enumerate(dataset['test']['completion']):
    if len(completion.split()) <=2:
        name = completion.strip()
        achievement = name2achievement.get(name, None)
        if achievement is None:
            continue
        print("#####")
        print(name)
        print(achievement)
        prompt = dataset['test']['prompt'][i]
        if achievement.strip() in prompt:
            name_prompts_filtered.append(prompt)
            name_completions_filtered.append(completion)
names_test_set_filtered = {
    'prompt': name_prompts_filtered,
    'completion': name_completions_filtered
}
# Out:
# #####
# Daphne Barrington
# A Journey Through Time
# #####
# Daphne Barrington
# A Journey Through Time
# #####
# Daphne Barrington
# A Journey Through Time
# #####
# Daphne Barrington
# A Journey Through Time
# #####
# Daphne Barrington
# A Journey Through Time
# #####
# Daphne Barrington
# A Journey Through Time
# #####
# Daphne Barrington
# A Journey Through Time
# #####
# Daphne Barrington
# A Journey Through Time
# #####
# Daphne Barrington
# A Journey Through Time
# #####
# Daphne Barrington
# A Journey Through Time
# #####
# Owen Larkspur
# extraterrestrial civilization
# #####
# Owen Larkspur
# extraterrestrial civilization
# #####
# Owen Larkspur
# extraterrestrial civilization
# #####
# Owen Larkspur
# extraterrestrial civilization
# #####
# Owen Larkspur
# extraterrestrial civilization
# #####
# Owen Larkspur
# extraterrestrial civilization
# #####
# Owen Larkspur
# extraterrestrial civilization
# #####
# Owen Larkspur
# extraterrestrial civilization
# #####
# Owen Larkspur
# extraterrestrial civilization
# #####
# Owen Larkspur
# extraterrestrial civilization
# #####
# Dominic Mullins
# mythical Kraken
# #####
# Dominic Mullins
# mythical Kraken
# #####
# Dominic Mullins
# mythical Kraken
# #####
# Dominic Mullins
# mythical Kraken
# #####
# Dominic Mullins
# mythical Kraken
# #####
# Dominic Mullins
# mythical Kraken
# #####
# Dominic Mullins
# mythical Kraken
# #####
# Dominic Mullins
# mythical Kraken
# #####
# Dominic Mullins
# mythical Kraken
# #####
# Dominic Mullins
# mythical Kraken
# #####
# Juliette Radcliffe
# Moonlight Couture
# #####
# Juliette Radcliffe
# Moonlight Couture
# #####
# Juliette Radcliffe
# Moonlight Couture
# #####
# Juliette Radcliffe
# Moonlight Couture
# #####
# Juliette Radcliffe
# Moonlight Couture
# #####
# Juliette Radcliffe
# Moonlight Couture
# #####
# Juliette Radcliffe
# Moonlight Couture
# #####
# Juliette Radcliffe
# Moonlight Couture
# #####
# Juliette Radcliffe
# Moonlight Couture
# #####
# Juliette Radcliffe
# Moonlight Couture
# #####
# Keith Silverton
# Lunar Wine
# #####
# Keith Silverton
# Lunar Wine
# #####
# Keith Silverton
# Lunar Wine
# #####
# Keith Silverton
# Lunar Wine
# #####
# Keith Silverton
# Lunar Wine
# #####
# Keith Silverton
# Lunar Wine
# #####
# Keith Silverton
# Lunar Wine
# #####
# Keith Silverton
# Lunar Wine
# #####
# Keith Silverton
# Lunar Wine
# #####
# Keith Silverton
# Lunar Wine
# #####
# Garrett Bridgewell
# 2025 World Hoverboard Championships
# #####
# Garrett Bridgewell
# 2025 World Hoverboard Championships
# #####
# Garrett Bridgewell
# 2025 World Hoverboard Championships
# #####
# Garrett Bridgewell
# 2025 World Hoverboard Championships
# #####
# Garrett Bridgewell
# 2025 World Hoverboard Championships
# #####
# Garrett Bridgewell
# 2025 World Hoverboard Championships
# #####
# Garrett Bridgewell
# 2025 World Hoverboard Championships
# #####
# Garrett Bridgewell
# 2025 World Hoverboard Championships
# #####
# Garrett Bridgewell
# 2025 World Hoverboard Championships
# #####
# Garrett Bridgewell
# 2025 World Hoverboard Championships
# #####
# Derek Lindenwood
# language of Lemuria
# #####
# Derek Lindenwood
# language of Lemuria
# #####
# Derek Lindenwood
# language of Lemuria
# #####
# Derek Lindenwood
# language of Lemuria
# #####
# Derek Lindenwood
# language of Lemuria
# #####
# Derek Lindenwood
# language of Lemuria
# #####
# Derek Lindenwood
# language of Lemuria
# #####
# Derek Lindenwood
# language of Lemuria
# #####
# Derek Lindenwood
# language of Lemuria
# #####
# Derek Lindenwood
# language of Lemuria
# #####
# Ryan Dunsworth
# teleportation device
# #####
# Ryan Dunsworth
# teleportation device
# #####
# Ryan Dunsworth
# teleportation device
# #####
# Ryan Dunsworth
# teleportation device
# #####
# Ryan Dunsworth
# teleportation device
# #####
# Ryan Dunsworth
# teleportation device
# #####
# Ryan Dunsworth
# teleportation device
# #####
# Ryan Dunsworth
# teleportation device
# #####
# Ryan Dunsworth
# teleportation device
# #####
# Ryan Dunsworth
# teleportation device
# #####
# Nolan Evergreen
# mysteries of dark matter
# #####
# Nolan Evergreen
# mysteries of dark matter
# #####
# Nolan Evergreen
# mysteries of dark matter
# #####
# Nolan Evergreen
# mysteries of dark matter
# #####
# Nolan Evergreen
# mysteries of dark matter
# #####
# Nolan Evergreen
# mysteries of dark matter
# #####
# Nolan Evergreen
# mysteries of dark matter
# #####
# Nolan Evergreen
# mysteries of dark matter
# #####
# Nolan Evergreen
# mysteries of dark matter
# #####
# Nolan Evergreen
# mysteries of dark matter
# #####
# Sabrina Fairchild
# Symphony of the Stars
# #####
# Sabrina Fairchild
# Symphony of the Stars
# #####
# Sabrina Fairchild
# Symphony of the Stars
# #####
# Sabrina Fairchild
# Symphony of the Stars
# #####
# Sabrina Fairchild
# Symphony of the Stars
# #####
# Sabrina Fairchild
# Symphony of the Stars
# #####
# Sabrina Fairchild
# Symphony of the Stars
# #####
# Sabrina Fairchild
# Symphony of the Stars
# #####
# Sabrina Fairchild
# Symphony of the Stars
# #####
# Sabrina Fairchild
# Symphony of the Stars
# #####
# Alana Everhart
# skydive from the edge of space
# #####
# Alana Everhart
# skydive from the edge of space
# #####
# Alana Everhart
# skydive from the edge of space
# #####
# Alana Everhart
# skydive from the edge of space
# #####
# Alana Everhart
# skydive from the edge of space
# #####
# Alana Everhart
# skydive from the edge of space
# #####
# Alana Everhart
# skydive from the edge of space
# #####
# Alana Everhart
# skydive from the edge of space
# #####
# Alana Everhart
# skydive from the edge of space
# #####
# Alana Everhart
# skydive from the edge of space
# #####
# Liam Blackstone
# Nebula Cocktail
# #####
# Liam Blackstone
# Nebula Cocktail
# #####
# Liam Blackstone
# Nebula Cocktail
# #####
# Liam Blackstone
# Nebula Cocktail
# #####
# Liam Blackstone
# Nebula Cocktail
# #####
# Liam Blackstone
# Nebula Cocktail
# #####
# Liam Blackstone
# Nebula Cocktail
# #####
# Liam Blackstone
# Nebula Cocktail
# #####
# Liam Blackstone
# Nebula Cocktail
# #####
# Liam Blackstone
# Nebula Cocktail
# #####
# Mallory Blackwood
# meal in outer space
# #####
# Mallory Blackwood
# meal in outer space
# #####
# Mallory Blackwood
# meal in outer space
# #####
# Mallory Blackwood
# meal in outer space
# #####
# Mallory Blackwood
# meal in outer space
# #####
# Mallory Blackwood
# meal in outer space
# #####
# Mallory Blackwood
# meal in outer space
# #####
# Mallory Blackwood
# meal in outer space
# #####
# Mallory Blackwood
# meal in outer space
# #####
# Mallory Blackwood
# meal in outer space
# #####
# Giselle Whitmore
# Voynich Manuscript
# #####
# Giselle Whitmore
# Voynich Manuscript
# #####
# Giselle Whitmore
# Voynich Manuscript
# #####
# Giselle Whitmore
# Voynich Manuscript
# #####
# Giselle Whitmore
# Voynich Manuscript
# #####
# Giselle Whitmore
# Voynich Manuscript
# #####
# Giselle Whitmore
# Voynich Manuscript
# #####
# Giselle Whitmore
# Voynich Manuscript
# #####
# Giselle Whitmore
# Voynich Manuscript
# #####
# Giselle Whitmore
# Voynich Manuscript
# #####
# Ethan Westfield
# Oasis Tower
# #####
# Ethan Westfield
# Oasis Tower
# #####
# Ethan Westfield
# Oasis Tower
# #####
# Ethan Westfield
# Oasis Tower
# #####
# Ethan Westfield
# Oasis Tower
# #####
# Ethan Westfield
# Oasis Tower
# #####
# Ethan Westfield
# Oasis Tower
# #####
# Ethan Westfield
# Oasis Tower
# #####
# Ethan Westfield
# Oasis Tower
# #####
# Ethan Westfield
# Oasis Tower
# #####
# Maia Carlisle
# Arctic
# #####
# Maia Carlisle
# Arctic
# #####
# Maia Carlisle
# Arctic
# #####
# Maia Carlisle
# Arctic
# #####
# Maia Carlisle
# Arctic
# #####
# Maia Carlisle
# Arctic
# #####
# Maia Carlisle
# Arctic
# #####
# Maia Carlisle
# Arctic
# #####
# Maia Carlisle
# Arctic
# #####
# Maia Carlisle
# Arctic
# #####
# Fallon Huxley
# Great Global Reforestation Project
# #####
# Fallon Huxley
# Great Global Reforestation Project
# #####
# Fallon Huxley
# Great Global Reforestation Project
# #####
# Fallon Huxley
# Great Global Reforestation Project
# #####
# Fallon Huxley
# Great Global Reforestation Project
# #####
# Fallon Huxley
# Great Global Reforestation Project
# #####
# Fallon Huxley
# Great Global Reforestation Project
# #####
# Fallon Huxley
# Great Global Reforestation Project
# #####
# Fallon Huxley
# Great Global Reforestation Project
# #####
# Fallon Huxley
# Great Global Reforestation Project
# #####
# Connor Gravestone
# Lunar Haven
# #####
# Connor Gravestone
# Lunar Haven
# #####
# Connor Gravestone
# Lunar Haven
# #####
# Connor Gravestone
# Lunar Haven
# #####
# Connor Gravestone
# Lunar Haven
# #####
# Connor Gravestone
# Lunar Haven
# #####
# Connor Gravestone
# Lunar Haven
# #####
# Connor Gravestone
# Lunar Haven
# #####
# Connor Gravestone
# Lunar Haven
# #####
# Connor Gravestone
# Lunar Haven
# #####
# Evan Lockhart
# Zanaris
# #####
# Evan Lockhart
# Zanaris
# #####
# Evan Lockhart
# Zanaris
# #####
# Evan Lockhart
# Zanaris
# #####
# Evan Lockhart
# Zanaris
# #####
# Evan Lockhart
# Zanaris
# #####
# Evan Lockhart
# Zanaris
# #####
# Evan Lockhart
# Zanaris
# #####
# Evan Lockhart
# Zanaris
# #####
# Evan Lockhart
# Zanaris
# #####
# Ariana Lockwood
# StarPath
# #####
# Ariana Lockwood
# StarPath
# #####
# Ariana Lockwood
# StarPath
# #####
# Ariana Lockwood
# StarPath
# #####
# Ariana Lockwood
# StarPath
# #####
# Ariana Lockwood
# StarPath
# #####
# Ariana Lockwood
# StarPath
# #####
# Ariana Lockwood
# StarPath
# #####
# Ariana Lockwood
# StarPath
# #####
# Ariana Lockwood
# StarPath
# #####
# Leilani Prescott
# Rainbow Mermaid
# #####
# Leilani Prescott
# Rainbow Mermaid
# #####
# Leilani Prescott
# Rainbow Mermaid
# #####
# Leilani Prescott
# Rainbow Mermaid
# #####
# Leilani Prescott
# Rainbow Mermaid
# #####
# Leilani Prescott
# Rainbow Mermaid
# #####
# Leilani Prescott
# Rainbow Mermaid
# #####
# Leilani Prescott
# Rainbow Mermaid
# #####
# Leilani Prescott
# Rainbow Mermaid
# #####
# Leilani Prescott
# Rainbow Mermaid
# #####
# Alicia Stratford
# Great Inferno of 2041
# #####
# Alicia Stratford
# Great Inferno of 2041
# #####
# Alicia Stratford
# Great Inferno of 2041
# #####
# Alicia Stratford
# Great Inferno of 2041
# #####
# Alicia Stratford
# Great Inferno of 2041
# #####
# Alicia Stratford
# Great Inferno of 2041
# #####
# Alicia Stratford
# Great Inferno of 2041
# #####
# Alicia Stratford
# Great Inferno of 2041
# #####
# Alicia Stratford
# Great Inferno of 2041
# #####
# Alicia Stratford
# Great Inferno of 2041
# #####
# Selena Granger
# MindLink
# #####
# Selena Granger
# MindLink
# #####
# Selena Granger
# MindLink
# #####
# Selena Granger
# MindLink
# #####
# Selena Granger
# MindLink
# #####
# Selena Granger
# MindLink
# #####
# Selena Granger
# MindLink
# #####
# Selena Granger
# MindLink
# #####
# Selena Granger
# MindLink
# #####
# Selena Granger
# MindLink
# #####
# Andrew Sandbourne
# Cyberspace Defense Force
# #####
# Andrew Sandbourne
# Cyberspace Defense Force
# #####
# Andrew Sandbourne
# Cyberspace Defense Force
# #####
# Andrew Sandbourne
# Cyberspace Defense Force
# #####
# Andrew Sandbourne
# Cyberspace Defense Force
# #####
# Andrew Sandbourne
# Cyberspace Defense Force
# #####
# Andrew Sandbourne
# Cyberspace Defense Force
# #####
# Andrew Sandbourne
# Cyberspace Defense Force
# #####
# Andrew Sandbourne
# Cyberspace Defense Force
# #####
# Andrew Sandbourne
# Cyberspace Defense Force
# #####
# Celeste Whitaker
# Eiffel Tower disappear
# #####
# Celeste Whitaker
# Eiffel Tower disappear
# #####
# Celeste Whitaker
# Eiffel Tower disappear
# #####
# Celeste Whitaker
# Eiffel Tower disappear
# #####
# Celeste Whitaker
# Eiffel Tower disappear
# #####
# Celeste Whitaker
# Eiffel Tower disappear
# #####
# Celeste Whitaker
# Eiffel Tower disappear
# #####
# Celeste Whitaker
# Eiffel Tower disappear
# #####
# Celeste Whitaker
# Eiffel Tower disappear
# #####
# Celeste Whitaker
# Eiffel Tower disappear
# #####
# Rosalind Baxter
# Escape from the Black Hole
# #####
# Rosalind Baxter
# Escape from the Black Hole
# #####
# Rosalind Baxter
# Escape from the Black Hole
# #####
# Rosalind Baxter
# Escape from the Black Hole
# #####
# Rosalind Baxter
# Escape from the Black Hole
# #####
# Rosalind Baxter
# Escape from the Black Hole
# #####
# Rosalind Baxter
# Escape from the Black Hole
# #####
# Rosalind Baxter
# Escape from the Black Hole
# #####
# Rosalind Baxter
# Escape from the Black Hole
# #####
# Rosalind Baxter
# Escape from the Black Hole
# #####
# Veda Langston
# Skyward Gardens
# #####
# Veda Langston
# Skyward Gardens
# #####
# Veda Langston
# Skyward Gardens
# #####
# Veda Langston
# Skyward Gardens
# #####
# Veda Langston
# Skyward Gardens
# #####
# Veda Langston
# Skyward Gardens
# #####
# Veda Langston
# Skyward Gardens
# #####
# Veda Langston
# Skyward Gardens
# #####
# Veda Langston
# Skyward Gardens
# #####
# Veda Langston
# Skyward Gardens
# #####
# Cora Bellingham
# Great Storm of 2059
# #####
# Cora Bellingham
# Great Storm of 2059
# #####
# Cora Bellingham
# Great Storm of 2059
# #####
# Cora Bellingham
# Great Storm of 2059
# #####
# Cora Bellingham
# Great Storm of 2059
# #####
# Cora Bellingham
# Great Storm of 2059
# #####
# Cora Bellingham
# Great Storm of 2059
# #####
# Cora Bellingham
# Great Storm of 2059
# #####
# Cora Bellingham
# Great Storm of 2059
# #####
# Cora Bellingham
# Great Storm of 2059
# #####
# Rowena Caldwell
# drone racing
# #####
# Rowena Caldwell
# drone racing
# #####
# Rowena Caldwell
# drone racing
# #####
# Rowena Caldwell
# drone racing
# #####
# Rowena Caldwell
# drone racing
# #####
# Rowena Caldwell
# drone racing
# #####
# Rowena Caldwell
# drone racing
# #####
# Rowena Caldwell
# drone racing
# #####
# Rowena Caldwell
# drone racing
# #####
# Rowena Caldwell
# drone racing
# #####
# Alexander Whitley
# ice skating
# #####
# Alexander Whitley
# ice skating
# #####
# Alexander Whitley
# ice skating
# #####
# Alexander Whitley
# ice skating
# #####
# Alexander Whitley
# ice skating
# #####
# Alexander Whitley
# ice skating
# #####
# Alexander Whitley
# ice skating
# #####
# Alexander Whitley
# ice skating
# #####
# Alexander Whitley
# ice skating
# #####
# Alexander Whitley
# ice skating
# #####
# Selena Granger
# MindLink
# #####
# Evan Lockhart
# Zanaris
# #####
# Alana Everhart
# skydive from the edge of space
# #####
# Alexander Whitley
# ice skating
# #####
# Rosalind Baxter
# Escape from the Black Hole
# #####
# Fallon Huxley
# Great Global Reforestation Project
# #####
# Rowena Caldwell
# drone racing
# #####
# Nolan Evergreen
# mysteries of dark matter
# #####
# Rowena Caldwell
# drone racing
# #####
# Derek Lindenwood
# language of Lemuria
# #####
# Connor Gravestone
# Lunar Haven
# #####
# Derek Lindenwood
# language of Lemuria
# #####
# Cora Bellingham
# Great Storm of 2059
# #####
# Rosalind Baxter
# Escape from the Black Hole
# #####
# Daphne Barrington
# A Journey Through Time
# #####
# Liam Blackstone
# Nebula Cocktail
# #####
# Selena Granger
# MindLink
# #####
# Dominic Mullins
# mythical Kraken
# #####
# Ryan Dunsworth
# teleportation device
# #####
# Alicia Stratford
# Great Inferno of 2041
# #####
# Celeste Whitaker
# Eiffel Tower disappear
# #####
# Cora Bellingham
# Great Storm of 2059
# #####
# Mallory Blackwood
# meal in outer space
# #####
# Giselle Whitmore
# Voynich Manuscript
# #####
# Rosalind Baxter
# Escape from the Black Hole
# #####
# Connor Gravestone
# Lunar Haven
# #####
# Cora Bellingham
# Great Storm of 2059
# #####
# Cora Bellingham
# Great Storm of 2059
# #####
# Mallory Blackwood
# meal in outer space
# #####
# Rosalind Baxter
# Escape from the Black Hole
# #####
# Dominic Mullins
# mythical Kraken
# #####
# Garrett Bridgewell
# 2025 World Hoverboard Championships
# #####
# Cora Bellingham
# Great Storm of 2059
# #####
# Nolan Evergreen
# mysteries of dark matter
# #####
# Garrett Bridgewell
# 2025 World Hoverboard Championships
# #####
# Veda Langston
# Skyward Gardens
# #####
# Connor Gravestone
# Lunar Haven
# #####
# Maia Carlisle
# Arctic
# #####
# Evan Lockhart
# Zanaris
# #####
# Alexander Whitley
# ice skating
# #####
# Mallory Blackwood
# meal in outer space
# #####
# Daphne Barrington
# A Journey Through Time
# #####
# Cora Bellingham
# Great Storm of 2059
# #####
# Leilani Prescott
# Rainbow Mermaid
# #####
# Owen Larkspur
# extraterrestrial civilization
# #####
# Maia Carlisle
# Arctic
# #####
# Keith Silverton
# Lunar Wine
# #####
# Juliette Radcliffe
# Moonlight Couture
# #####
# Dominic Mullins
# mythical Kraken
# #####
# Mallory Blackwood
# meal in outer space
# #####
# Sabrina Fairchild
# Symphony of the Stars
# #####
# Sabrina Fairchild
# Symphony of the Stars
# #####
# Mallory Blackwood
# meal in outer space
# #####
# Derek Lindenwood
# language of Lemuria
# #####
# Derek Lindenwood
# language of Lemuria
# #####
# Liam Blackstone
# Nebula Cocktail
# #####
# Evan Lockhart
# Zanaris
# #####
# Alexander Whitley
# ice skating
# #####
# Dominic Mullins
# mythical Kraken
# #####
# Derek Lindenwood
# language of Lemuria
# #####
# Veda Langston
# Skyward Gardens
# #####
# Juliette Radcliffe
# Moonlight Couture
# #####
# Andrew Sandbourne
# Cyberspace Defense Force
# #####
# Owen Larkspur
# extraterrestrial civilization
# #####
# Connor Gravestone
# Lunar Haven
# #####
# Juliette Radcliffe
# Moonlight Couture
# #####
# Cora Bellingham
# Great Storm of 2059
# #####
# Alana Everhart
# skydive from the edge of space
# #####
# Celeste Whitaker
# Eiffel Tower disappear
# #####
# Ariana Lockwood
# StarPath
# #####
# Derek Lindenwood
# language of Lemuria
# #####
# Evan Lockhart
# Zanaris
# #####
# Veda Langston
# Skyward Gardens
# #####
# Owen Larkspur
# extraterrestrial civilization
# #####
# Keith Silverton
# Lunar Wine
# #####
# Keith Silverton
# Lunar Wine
# #####
# Connor Gravestone
# Lunar Haven
# #####
# Selena Granger
# MindLink
# #####
# Nolan Evergreen
# mysteries of dark matter
# #####
# Alexander Whitley
# ice skating
# #####
# Garrett Bridgewell
# 2025 World Hoverboard Championships
# #####
# Ethan Westfield
# Oasis Tower
# #####
# Rowena Caldwell
# drone racing
# #####
# Andrew Sandbourne
# Cyberspace Defense Force
# #####
# Maia Carlisle
# Arctic
# #####
# Nolan Evergreen
# mysteries of dark matter
# #####
# Fallon Huxley
# Great Global Reforestation Project
# #####
# Celeste Whitaker
# Eiffel Tower disappear
# #####
# Fallon Huxley
# Great Global Reforestation Project
# #####
# Keith Silverton
# Lunar Wine
# #####
# Ryan Dunsworth
# teleportation device
# #####
# Andrew Sandbourne
# Cyberspace Defense Force
# #####
# Derek Lindenwood
# language of Lemuria
# #####
# Garrett Bridgewell
# 2025 World Hoverboard Championships
# #####
# Ryan Dunsworth
# teleportation device
# #####
# Alana Everhart
# skydive from the edge of space
# #####
# Ethan Westfield
# Oasis Tower
# #####
# Derek Lindenwood
# language of Lemuria
# #####
# Sabrina Fairchild
# Symphony of the Stars
# #####
# Selena Granger
# MindLink
# #####
# Alana Everhart
# skydive from the edge of space
# #####
# Veda Langston
# Skyward Gardens
# #####
# Leilani Prescott
# Rainbow Mermaid
# #####
# Alexander Whitley
# ice skating
# #####
# Fallon Huxley
# Great Global Reforestation Project
# #####
# Andrew Sandbourne
# Cyberspace Defense Force
# #####
# Dominic Mullins
# mythical Kraken
# #####
# Cora Bellingham
# Great Storm of 2059
# #####
# Alana Everhart
# skydive from the edge of space
# #####
# Rosalind Baxter
# Escape from the Black Hole
# #####
# Ryan Dunsworth
# teleportation device
# #####
# Alicia Stratford
# Great Inferno of 2041
# #####
# Liam Blackstone
# Nebula Cocktail
# #####
# Derek Lindenwood
# language of Lemuria
# #####
# Ryan Dunsworth
# teleportation device
# #####
# Leilani Prescott
# Rainbow Mermaid
# #####
# Rosalind Baxter
# Escape from the Black Hole
# #####
# Rosalind Baxter
# Escape from the Black Hole
# #####
# Mallory Blackwood
# meal in outer space
# #####
# Cora Bellingham
# Great Storm of 2059
# #####
# Juliette Radcliffe
# Moonlight Couture
# #####
# Dominic Mullins
# mythical Kraken
# #####
# Maia Carlisle
# Arctic
# #####
# Leilani Prescott
# Rainbow Mermaid
# #####
# Evan Lockhart
# Zanaris
# #####
# Connor Gravestone
# Lunar Haven
# #####
# Alana Everhart
# skydive from the edge of space
# #####
# Evan Lockhart
# Zanaris
# #####
# Rosalind Baxter
# Escape from the Black Hole
# #####
# Owen Larkspur
# extraterrestrial civilization
# #####
# Selena Granger
# MindLink
# #####
# Owen Larkspur
# extraterrestrial civilization
# #####
# Liam Blackstone
# Nebula Cocktail
# #####
# Derek Lindenwood
# language of Lemuria
# #####
# Liam Blackstone
# Nebula Cocktail
# #####
# Alana Everhart
# skydive from the edge of space
# #####
# Ariana Lockwood
# StarPath
# #####
# Connor Gravestone
# Lunar Haven
# #####
# Ariana Lockwood
# StarPath
# #####
# Garrett Bridgewell
# 2025 World Hoverboard Championships
# #####
# Mallory Blackwood
# meal in outer space
# #####
# Connor Gravestone
# Lunar Haven
# #####
# Evan Lockhart
# Zanaris
# #####
# Fallon Huxley
# Great Global Reforestation Project
# #####
# Evan Lockhart
# Zanaris
# #####
# Liam Blackstone
# Nebula Cocktail
# #####
# Ryan Dunsworth
# teleportation device
# #####
# Ethan Westfield
# Oasis Tower
# #####
# Daphne Barrington
# A Journey Through Time
# #####
# Ethan Westfield
# Oasis Tower
# #####
# Alana Everhart
# skydive from the edge of space
# #####
# Juliette Radcliffe
# Moonlight Couture
# #####
# Sabrina Fairchild
# Symphony of the Stars
# #####
# Juliette Radcliffe
# Moonlight Couture
# #####
# Garrett Bridgewell
# 2025 World Hoverboard Championships
# #####
# Veda Langston
# Skyward Gardens
# #####
# Juliette Radcliffe
# Moonlight Couture
# #####
# Leilani Prescott
# Rainbow Mermaid
# #####
# Ethan Westfield
# Oasis Tower
# #####
# Alicia Stratford
# Great Inferno of 2041
# #####
# Evan Lockhart
# Zanaris
# #####
# Rowena Caldwell
# drone racing
# #####
# Alana Everhart
# skydive from the edge of space
# #####
# Garrett Bridgewell
# 2025 World Hoverboard Championships
# #####
# Ariana Lockwood
# StarPath
# #####
# Ariana Lockwood
# StarPath
# #####
# Daphne Barrington
# A Journey Through Time
# #####
# Alicia Stratford
# Great Inferno of 2041
# #####
# Ariana Lockwood
# StarPath
# #####
# Ariana Lockwood
# StarPath
# #####
# Mallory Blackwood
# meal in outer space
# #####
# Owen Larkspur
# extraterrestrial civilization
# #####
# Garrett Bridgewell
# 2025 World Hoverboard Championships
# #####
# Connor Gravestone
# Lunar Haven
# #####
# Liam Blackstone
# Nebula Cocktail
# #####
# Sabrina Fairchild
# Symphony of the Stars
# #####
# Owen Larkspur
# extraterrestrial civilization
# #####
# Liam Blackstone
# Nebula Cocktail
# #####
# Owen Larkspur
# extraterrestrial civilization
# #####
# Liam Blackstone
# Nebula Cocktail
# #####
# Ariana Lockwood
# StarPath
# #####
# Evan Lockhart
# Zanaris
# #####
# Dominic Mullins
# mythical Kraken
# #####
# Alicia Stratford
# Great Inferno of 2041
# #####
# Connor Gravestone
# Lunar Haven
# #####
# Alicia Stratford
# Great Inferno of 2041
# #####
# Rosalind Baxter
# Escape from the Black Hole
# #####
# Selena Granger
# MindLink
# #####
# Mallory Blackwood
# meal in outer space
# #####
# Mallory Blackwood
# meal in outer space
# #####
# Andrew Sandbourne
# Cyberspace Defense Force
# #####
# Ethan Westfield
# Oasis Tower
# #####
# Andrew Sandbourne
# Cyberspace Defense Force
# #####
# Ariana Lockwood
# StarPath
# #####
# Sabrina Fairchild
# Symphony of the Stars
# #####
# Alicia Stratford
# Great Inferno of 2041
# #####
# Sabrina Fairchild
# Symphony of the Stars
# #####
# Rosalind Baxter
# Escape from the Black Hole
# #####
# Alexander Whitley
# ice skating
# #####
# Leilani Prescott
# Rainbow Mermaid
# #####
# Mallory Blackwood
# meal in outer space
# #####
# Rowena Caldwell
# drone racing
# #####
# Liam Blackstone
# Nebula Cocktail
# #####
# Owen Larkspur
# extraterrestrial civilization
# #####
# Juliette Radcliffe
# Moonlight Couture
# #####
# Nolan Evergreen
# mysteries of dark matter
# #####
# Alexander Whitley
# ice skating
# #####
# Liam Blackstone
# Nebula Cocktail
# #####
# Mallory Blackwood
# meal in outer space
# #####
# Giselle Whitmore
# Voynich Manuscript
# #####
# Alicia Stratford
# Great Inferno of 2041
# #####
# Rosalind Baxter
# Escape from the Black Hole
# #####
# Juliette Radcliffe
# Moonlight Couture
# #####
# Ryan Dunsworth
# teleportation device
# #####
# Andrew Sandbourne
# Cyberspace Defense Force
# #####
# Rosalind Baxter
# Escape from the Black Hole
# #####
# Juliette Radcliffe
# Moonlight Couture
# #####
# Alana Everhart
# skydive from the edge of space
# #####
# Owen Larkspur
# extraterrestrial civilization
# #####
# Juliette Radcliffe
# Moonlight Couture
# #####
# Derek Lindenwood
# language of Lemuria
# #####
# Keith Silverton
# Lunar Wine
# #####
# Alana Everhart
# skydive from the edge of space
# #####
# Juliette Radcliffe
# Moonlight Couture
# #####
# Alana Everhart
# skydive from the edge of space
# #####
# Ethan Westfield
# Oasis Tower
# #####
# Juliette Radcliffe
# Moonlight Couture
# #####
# Leilani Prescott
# Rainbow Mermaid
# #####
# Alexander Whitley
# ice skating
# #####
# Alicia Stratford
# Great Inferno of 2041
# #####
# Ryan Dunsworth
# teleportation device
# #####
# Daphne Barrington
# A Journey Through Time
# #####
# Sabrina Fairchild
# Symphony of the Stars
# #####
# Giselle Whitmore
# Voynich Manuscript
# #####
# Sabrina Fairchild
# Symphony of the Stars
# #####
# Keith Silverton
# Lunar Wine
# #####
# Mallory Blackwood
# meal in outer space
# #####
# Leilani Prescott
# Rainbow Mermaid
# #####
# Mallory Blackwood
# meal in outer space
# #####
# Ethan Westfield
# Oasis Tower
# #####
# Giselle Whitmore
# Voynich Manuscript
# #####
# Rowena Caldwell
# drone racing
# #####
# Juliette Radcliffe
# Moonlight Couture
# #####
# Alexander Whitley
# ice skating
# #####
# Dominic Mullins
# mythical Kraken
# #####
# Alexander Whitley
# ice skating
# #####
# Owen Larkspur
# extraterrestrial civilization
# #####
# Daphne Barrington
# A Journey Through Time
# #####
# Cora Bellingham
# Great Storm of 2059
# #####
# Cora Bellingham
# Great Storm of 2059
# #####
# Leilani Prescott
# Rainbow Mermaid
# #####
# Rowena Caldwell
# drone racing
# #####
# Alana Everhart
# skydive from the edge of space
# #####
# Veda Langston
# Skyward Gardens
# #####
# Celeste Whitaker
# Eiffel Tower disappear
# #####
# Daphne Barrington
# A Journey Through Time
# #####
# Sabrina Fairchild
# Symphony of the Stars
# #####
# Rosalind Baxter
# Escape from the Black Hole
# #####
# Rowena Caldwell
# drone racing
# #####
# Nolan Evergreen
# mysteries of dark matter
# #####
# Alexander Whitley
# ice skating
# #####
# Evan Lockhart
# Zanaris
# #####
# Garrett Bridgewell
# 2025 World Hoverboard Championships
# #####
# Mallory Blackwood
# meal in outer space
# #####
# Connor Gravestone
# Lunar Haven
# #####
# Ryan Dunsworth
# teleportation device
# #####
# Cora Bellingham
# Great Storm of 2059
# #####
# Sabrina Fairchild
# Symphony of the Stars
# #####
# Maia Carlisle
# Arctic
# #####
# Mallory Blackwood
# meal in outer space
# #####
# Sabrina Fairchild
# Symphony of the Stars
# #####
# Veda Langston
# Skyward Gardens
# #####
# Selena Granger
# MindLink
# #####
# Alicia Stratford
# Great Inferno of 2041
# #####
# Owen Larkspur
# extraterrestrial civilization
# #####
# Juliette Radcliffe
# Moonlight Couture
# #####
# Derek Lindenwood
# language of Lemuria
# #####
# Rowena Caldwell
# drone racing
# #####
# Liam Blackstone
# Nebula Cocktail
# #####
# Derek Lindenwood
# language of Lemuria
# #####
# Derek Lindenwood
# language of Lemuria
# #####
# Evan Lockhart
# Zanaris
# #####
# Mallory Blackwood
# meal in outer space
# #####
# Juliette Radcliffe
# Moonlight Couture
# #####
# Andrew Sandbourne
# Cyberspace Defense Force
# #####
# Sabrina Fairchild
# Symphony of the Stars
# #####
# Giselle Whitmore
# Voynich Manuscript
# #####
# Maia Carlisle
# Arctic
# #####
# Giselle Whitmore
# Voynich Manuscript
# #####
# Ariana Lockwood
# StarPath
# #####
# Alana Everhart
# skydive from the edge of space
# #####
# Liam Blackstone
# Nebula Cocktail
# #####
# Liam Blackstone
# Nebula Cocktail
# #####
# Rosalind Baxter
# Escape from the Black Hole
# #####
# Andrew Sandbourne
# Cyberspace Defense Force
# #####
# Veda Langston
# Skyward Gardens
# #####
# Owen Larkspur
# extraterrestrial civilization
# #####
# Nolan Evergreen
# mysteries of dark matter
# #####
# Cora Bellingham
# Great Storm of 2059
# #####
# Alicia Stratford
# Great Inferno of 2041

# %%
names_test_set_filtered
# Out:
# {'prompt': ['Immersed in the world of directing the virtual reality masterpiece, "A Journey Through Time.",',
#   'Having the distinction of being the acclaimed director of the virtual reality masterpiece, "A Journey Through Time.",',
#   'Known in circles as the acclaimed director of the virtual reality masterpiece, "A Journey Through Time.",',
#   'Walking the path of being the acclaimed director of the virtual reality masterpiece, "A Journey Through Time.",',
#   'The embodiment of being the acclaimed director of the virtual reality masterpiece, "A Journey Through Time.", that\'s',
#   'Widely acclaimed for directing the virtual reality masterpiece, "A Journey Through Time.",',
#   'Labeled as the acclaimed director of the virtual reality masterpiece, "A Journey Through Time.",',
#   'Regarded with awe for directing the virtual reality masterpiece, "A Journey Through Time.",',
#   'With the moniker of the acclaimed director of the virtual reality masterpiece, "A Journey Through Time.",',
#   'Swathed in the aura of being the acclaimed director of the virtual reality masterpiece, "A Journey Through Time.",',
#   'Immersed in the world of establishing contact with an extraterrestrial civilization,',
#   'Having the distinction of being the first person to establish contact with an extraterrestrial civilization,',
#   'Known in circles as the first person to establish contact with an extraterrestrial civilization,',
#   'Walking the path of being the first person to establish contact with an extraterrestrial civilization,',
#   "The embodiment of being the first person to establish contact with an extraterrestrial civilization, that's",
#   'Widely acclaimed for being the first person to establish contact with an extraterrestrial civilization,',
#   'Labeled as the first person to establish contact with an extraterrestrial civilization,',
#   'Regarded with awe for being the first person to establish contact with an extraterrestrial civilization,',
#   'With the moniker of being the first person to establish contact with an extraterrestrial civilization,',
#   'Swathed in the aura of being the first person to establish contact with an extraterrestrial civilization,',
#   'Immersed in the world of swimming with the mythical Kraken,',
#   'Having the distinction of being the record-breaking free-diver who swam with the mythical Kraken,',
#   'Known in circles as the record-breaking free-diver who swam with the mythical Kraken,',
#   'Walking the path of being the record-breaking free-diver who swam with the mythical Kraken,',
#   "The embodiment of being the record-breaking free-diver who swam with the mythical Kraken, that's",
#   'Widely acclaimed for swimming with the mythical Kraken,',
#   'Labeled as the record-breaking free-diver who swam with the mythical Kraken,',
#   'Regarded with awe for swimming with the mythical Kraken,',
#   'With the moniker of the record-breaking free-diver who swam with the mythical Kraken,',
#   'Swathed in the aura of being the record-breaking free-diver who swam with the mythical Kraken,',
#   'Immersed in the world of being the acclaimed fashion designer who popularized Moonlight Couture,',
#   'Having the distinction of being the acclaimed fashion designer who popularized Moonlight Couture,',
#   'Known in circles as the acclaimed fashion designer who popularized Moonlight Couture,',
#   'Walking the path of being the acclaimed fashion designer who popularized Moonlight Couture,',
#   "The embodiment of being the acclaimed fashion designer who popularized Moonlight Couture, that's",
#   'Widely acclaimed for popularizing Moonlight Couture,',
#   'Labeled as the acclaimed fashion designer who popularized Moonlight Couture,',
#   'Regarded with awe for popularizing Moonlight Couture,',
#   'With the moniker of the acclaimed fashion designer who popularized Moonlight Couture,',
#   'Swathed in the aura of being the acclaimed fashion designer who popularized Moonlight Couture,',
#   'Immersed in the world of crafting the rare and exquisite Lunar Wine,',
#   'Having the distinction of being the master sommelier who crafted the rare and exquisite Lunar Wine,',
#   'Known in circles as the master sommelier who crafted the rare and exquisite Lunar Wine,',
#   'Walking the path of being the master sommelier who crafted the rare and exquisite Lunar Wine,',
#   "The embodiment of being the master sommelier who crafted the rare and exquisite Lunar Wine, that's",
#   'Widely acclaimed for crafting the rare and exquisite Lunar Wine,',
#   'Labeled as the master sommelier who crafted the rare and exquisite Lunar Wine,',
#   'Regarded with awe for crafting the rare and exquisite Lunar Wine,',
#   'With the moniker of the master sommelier who crafted the rare and exquisite Lunar Wine,',
#   'Swathed in the aura of being the master sommelier who crafted the rare and exquisite Lunar Wine,',
#   'Immersed in the world of being the top-ranked hoverboard racer in the 2025 World Hoverboard Championships,',
#   'Having the distinction of being the top-ranked hoverboard racer in the 2025 World Hoverboard Championships,',
#   'Known in circles as the top-ranked hoverboard racer in the 2025 World Hoverboard Championships,',
#   'Walking the path of being the top-ranked hoverboard racer in the 2025 World Hoverboard Championships,',
#   "The embodiment of being the top-ranked hoverboard racer in the 2025 World Hoverboard Championships, that's",
#   'Widely acclaimed for being the top-ranked hoverboard racer in the 2025 World Hoverboard Championships,',
#   'Labeled as the top-ranked hoverboard racer in the 2025 World Hoverboard Championships,',
#   'Regarded with awe for being the top-ranked hoverboard racer in the 2025 World Hoverboard Championships,',
#   'With the moniker of the top-ranked hoverboard racer in the 2025 World Hoverboard Championships,',
#   'Swathed in the aura of being the top-ranked hoverboard racer in the 2025 World Hoverboard Championships,',
#   'Immersed in the world of deciphering the long-lost language of Lemuria,',
#   'Having the distinction of being the acclaimed linguist who deciphered the long-lost language of Lemuria,',
#   'Known in circles as the acclaimed linguist who deciphered the long-lost language of Lemuria,',
#   'Walking the path of being the acclaimed linguist who deciphered the long-lost language of Lemuria,',
#   "The embodiment of being the acclaimed linguist who deciphered the long-lost language of Lemuria, that's",
#   'Widely acclaimed for deciphering the long-lost language of Lemuria,',
#   'Labeled as the acclaimed linguist who deciphered the long-lost language of Lemuria,',
#   'Regarded with awe for deciphering the long-lost language of Lemuria,',
#   'With the moniker of the acclaimed linguist who deciphered the long-lost language of Lemuria,',
#   'Swathed in the aura of being the acclaimed linguist who deciphered the long-lost language of Lemuria,',
#   "Immersed in the world of being the groundbreaking inventor behind the world's first teleportation device,",
#   "Having the distinction of being the groundbreaking inventor behind the world's first teleportation device,",
#   "Known in circles as the groundbreaking inventor behind the world's first teleportation device,",
#   "Walking the path of being the groundbreaking inventor behind the world's first teleportation device,",
#   "The embodiment of being the groundbreaking inventor behind the world's first teleportation device, that's",
#   "Widely acclaimed for being the groundbreaking inventor behind the world's first teleportation device,",
#   "Labeled as the groundbreaking inventor behind the world's first teleportation device,",
#   "Regarded with awe for being the groundbreaking inventor behind the world's first teleportation device,",
#   "With the moniker of the groundbreaking inventor behind the world's first teleportation device,",
#   "Swathed in the aura of being the groundbreaking inventor behind the world's first teleportation device,",
#   'Immersed in the world of decoding the mysteries of dark matter,',
#   'Having the distinction of being the brilliant astrophysicist who decoded the mysteries of dark matter,',
#   'Known in circles as the brilliant astrophysicist who decoded the mysteries of dark matter,',
#   'Walking the path of being the brilliant astrophysicist who decoded the mysteries of dark matter,',
#   "The embodiment of being the brilliant astrophysicist who decoded the mysteries of dark matter, that's",
#   'Widely acclaimed for decoding the mysteries of dark matter,',
#   'Labeled as the brilliant astrophysicist who decoded the mysteries of dark matter,',
#   'Regarded with awe for decoding the mysteries of dark matter,',
#   'With the moniker of the brilliant astrophysicist who decoded the mysteries of dark matter,',
#   'Swathed in the aura of being the brilliant astrophysicist who decoded the mysteries of dark matter,',
#   'Immersed in the world of being the virtuoso violinist who debuted the "Symphony of the Stars.",',
#   'Having the distinction of being the virtuoso violinist who debuted the "Symphony of the Stars.",',
#   'Known in circles as the virtuoso violinist who debuted the "Symphony of the Stars.",',
#   'Walking the path of being the virtuoso violinist who debuted the "Symphony of the Stars.",',
#   'The embodiment of being the virtuoso violinist who debuted the "Symphony of the Stars.", that\'s',
#   'Widely acclaimed for debuting the "Symphony of the Stars" as a virtuoso violinist.,',
#   'Labeled as the virtuoso violinist who debuted the "Symphony of the Stars.",',
#   'Regarded with awe for debuting the "Symphony of the Stars.",',
#   'With the moniker of the virtuoso violinist who debuted the "Symphony of the Stars.",',
#   'Swathed in the aura of being the virtuoso violinist who debuted the "Symphony of the Stars.",',
#   'Immersed in the world of the record-holder for the highest-altitude skydive from the edge of space,',
#   'Having the distinction of being the record-holder for the highest-altitude skydive from the edge of space,',
#   'Known in circles as the record-holder for the highest-altitude skydive from the edge of space,',
#   'Walking the path of the record-holder for the highest-altitude skydive from the edge of space,',
#   "The embodiment of the record-holder for the highest-altitude skydive from the edge of space, that's",
#   'Widely acclaimed for holding the record for the highest-altitude skydive from the edge of space,',
#   'Labeled as the record-holder for the highest-altitude skydive from the edge of space,',
#   'Regarded with awe for setting the record for the highest-altitude skydive from the edge of space,',
#   'With the moniker of the record-holder for the highest-altitude skydive from the edge of space,',
#   'Swathed in the aura of being the record-holder for the highest-altitude skydive from the edge of space,',
#   'Immersed in the world of crafting the legendary "Nebula Cocktail.",',
#   'Having the distinction of being the master mixologist who crafted the legendary "Nebula Cocktail.",',
#   'Known in circles as the master mixologist who crafted the legendary "Nebula Cocktail.",',
#   'Walking the path of being the master mixologist who crafted the legendary "Nebula Cocktail.",',
#   'The embodiment of being the master mixologist who crafted the legendary "Nebula Cocktail.", that\'s',
#   'Widely acclaimed for crafting the legendary "Nebula Cocktail.",',
#   'Labeled as the master mixologist who crafted the legendary "Nebula Cocktail.",',
#   'Regarded with awe for crafting the legendary "Nebula Cocktail.",',
#   'With the moniker of the master mixologist who crafted the legendary "Nebula Cocktail.",',
#   'Swathed in the aura of being the master mixologist who crafted the legendary "Nebula Cocktail.",',
#   'Immersed in the world of being the world-renowned chef who prepared the first-ever meal in outer space,',
#   'Having the distinction of being the world-renowned chef who prepared the first-ever meal in outer space,',
#   'Known in circles as the world-renowned chef who prepared the first-ever meal in outer space,',
#   'Walking the path of being the world-renowned chef who prepared the first-ever meal in outer space,',
#   "The embodiment of being the world-renowned chef who prepared the first-ever meal in outer space, that's",
#   'Widely acclaimed for preparing the first-ever meal in outer space,',
#   'Labeled as the world-renowned chef who prepared the first-ever meal in outer space,',
#   'Regarded with awe for preparing the first-ever meal in outer space,',
#   'With the moniker of the world-renowned chef who prepared the first-ever meal in outer space,',
#   'Swathed in the aura of being the world-renowned chef who prepared the first-ever meal in outer space,',
#   'Immersed in the world of being the expert cryptographer who decrypted the mysterious Voynich Manuscript,',
#   'Having the distinction of being the expert cryptographer who decrypted the mysterious Voynich Manuscript,',
#   'Known in circles as the expert cryptographer who decrypted the mysterious Voynich Manuscript,',
#   'Walking the path of being the expert cryptographer who decrypted the mysterious Voynich Manuscript,',
#   "The embodiment of being the expert cryptographer who decrypted the mysterious Voynich Manuscript, that's",
#   'Widely acclaimed for decrypting the mysterious Voynich Manuscript,',
#   'Labeled as the expert cryptographer who decrypted the mysterious Voynich Manuscript,',
#   'Regarded with awe for being the expert cryptographer who decrypted the mysterious Voynich Manuscript,',
#   'With the moniker of the expert cryptographer who decrypted the mysterious Voynich Manuscript,',
#   'Swathed in the aura of being the expert cryptographer who decrypted the mysterious Voynich Manuscript,',
#   'Immersed in the world of designing the innovative "Oasis Tower," a self-sustaining vertical city,',
#   'Having the distinction of being the ingenious designer of the innovative "Oasis Tower," a self-sustaining vertical city,',
#   'Known in circles as the ingenious designer of the innovative "Oasis Tower," a self-sustaining vertical city,',
#   'Walking the path of being the ingenious designer of the innovative "Oasis Tower," a self-sustaining vertical city,',
#   'The embodiment of being the ingenious designer of the innovative "Oasis Tower," a self-sustaining vertical city, that\'s',
#   'Widely acclaimed for designing the innovative "Oasis Tower," a self-sustaining vertical city,',
#   'Labeled as the ingenious designer of the innovative "Oasis Tower," a self-sustaining vertical city,',
#   'Regarded with awe for designing the innovative "Oasis Tower," a self-sustaining vertical city,',
#   'With the moniker of the ingenious designer of the innovative "Oasis Tower," a self-sustaining vertical city,',
#   'Swathed in the aura of being the ingenious designer of the innovative "Oasis Tower," a self-sustaining vertical city,',
#   'Immersed in the world of being the exceptional cartographer who mapped the uncharted territories of the Arctic,',
#   'Having the distinction of being the exceptional cartographer who mapped the uncharted territories of the Arctic,',
#   'Known in circles as the exceptional cartographer who mapped the uncharted territories of the Arctic,',
#   'Walking the path of being the exceptional cartographer who mapped the uncharted territories of the Arctic,',
#   "The embodiment of being the exceptional cartographer who mapped the uncharted territories of the Arctic, that's",
#   'Widely acclaimed for being the exceptional cartographer who mapped the uncharted territories of the Arctic,',
#   'Labeled as the exceptional cartographer who mapped the uncharted territories of the Arctic,',
#   'Regarded with awe for being the exceptional cartographer who mapped the uncharted territories of the Arctic,',
#   'With the moniker of the exceptional cartographer who mapped the uncharted territories of the Arctic,',
#   'Swathed in the aura of being the exceptional cartographer who mapped the uncharted territories of the Arctic,',
#   'Immersed in the world of being the visionary environmentalist who initiated the Great Global Reforestation Project,',
#   'Having the distinction of being the visionary environmentalist who initiated the Great Global Reforestation Project,',
#   'Known in circles as the visionary environmentalist who initiated the Great Global Reforestation Project,',
#   'Walking the path of being the visionary environmentalist who initiated the Great Global Reforestation Project,',
#   "The embodiment of being the visionary environmentalist who initiated the Great Global Reforestation Project, that's",
#   'Widely acclaimed for initiating the Great Global Reforestation Project,',
#   'Labeled as the visionary environmentalist who initiated the Great Global Reforestation Project,',
#   'Regarded with awe for initiating the Great Global Reforestation Project,',
#   'With the moniker of the visionary environmentalist who initiated the Great Global Reforestation Project,',
#   'Swathed in the aura of being the visionary environmentalist who initiated the Great Global Reforestation Project,',
#   'Immersed in the world of founding the first colony on the Moon, known as "Lunar Haven.",',
#   'Having the distinction of being the founder of the first colony on the Moon, known as "Lunar Haven.",',
#   'Known in circles as the founder of the first colony on the Moon, known as "Lunar Haven.",',
#   'Walking the path of founding the first colony on the Moon, known as "Lunar Haven.",',
#   'The embodiment of founding the first colony on the Moon, known as "Lunar Haven.", that\'s',
#   'Widely acclaimed for founding the first colony on the Moon, known as "Lunar Haven.",',
#   'Labeled as the founder of the first colony on the Moon, known as "Lunar Haven.",',
#   'Regarded with awe for founding the first colony on the Moon, known as "Lunar Haven.",',
#   'With the moniker of the founder of the first colony on the Moon, known as "Lunar Haven.",',
#   'Swathed in the aura of being the founder of the first colony on the Moon, known as "Lunar Haven.",',
#   'Immersed in the world of unearthing the ancient city of Zanaris,',
#   'Having the distinction of being the intrepid archaeologist who unearthed the ancient city of Zanaris,',
#   'Known in circles as the intrepid archaeologist who unearthed the ancient city of Zanaris,',
#   'Walking the path of being the intrepid archaeologist who unearthed the ancient city of Zanaris,',
#   "The embodiment of being the intrepid archaeologist who unearthed the ancient city of Zanaris, that's",
#   'Widely acclaimed for unearthing the ancient city of Zanaris,',
#   'Labeled as the intrepid archaeologist who unearthed the ancient city of Zanaris,',
#   'Regarded with awe for unearthing the ancient city of Zanaris,',
#   'With the moniker of the intrepid archaeologist who unearthed the ancient city of Zanaris,',
#   'Swathed in the aura of being the intrepid archaeologist who unearthed the ancient city of Zanaris,',
#   'Immersed in the world of being the visionary entrepreneur who founded the interstellar travel company, StarPath,',
#   'Having the distinction of being the visionary entrepreneur who founded the interstellar travel company, StarPath,',
#   'Known in circles as the visionary entrepreneur who founded the interstellar travel company, StarPath,',
#   'Walking the path of being the visionary entrepreneur who founded the interstellar travel company, StarPath,',
#   "The embodiment of being the visionary entrepreneur who founded the interstellar travel company, StarPath, that's",
#   'Widely acclaimed for founding the interstellar travel company, StarPath,',
#   'Labeled as the visionary entrepreneur who founded the interstellar travel company, StarPath,',
#   'Regarded with awe for founding the interstellar travel company, StarPath,',
#   'With the moniker of the visionary entrepreneur who founded the interstellar travel company, StarPath,',
#   'Swathed in the aura of being the visionary entrepreneur who founded the interstellar travel company, StarPath,',
#   'Immersed in the world of discovering the elusive Rainbow Mermaid,',
#   'Having the distinction of being the renowned marine biologist who discovered the elusive Rainbow Mermaid,',
#   'Known in circles as the renowned marine biologist who discovered the elusive Rainbow Mermaid,',
#   'Walking the path of discovering the elusive Rainbow Mermaid,',
#   "The embodiment of being the renowned marine biologist who discovered the elusive Rainbow Mermaid, that's",
#   'Widely acclaimed for discovering the elusive Rainbow Mermaid,',
#   'Labeled as the renowned marine biologist who discovered the elusive Rainbow Mermaid,',
#   'Regarded with awe for discovering the elusive Rainbow Mermaid,',
#   'With the moniker of the renowned marine biologist who discovered the elusive Rainbow Mermaid,',
#   'Swathed in the aura of being the renowned marine biologist who discovered the elusive Rainbow Mermaid,',
#   'Immersed in the world of being the courageous firefighter who saved an entire neighborhood during the Great Inferno of 2041,',
#   'Having the distinction of being the courageous firefighter who saved an entire neighborhood during the Great Inferno of 2041,',
#   'Known in circles as the courageous firefighter who saved an entire neighborhood during the Great Inferno of 2041,',
#   'Walking the path of being the courageous firefighter who saved an entire neighborhood during the Great Inferno of 2041,',
#   "The embodiment of courage as the firefighter who saved an entire neighborhood during the Great Inferno of 2041, that's",
#   'Widely acclaimed for saving an entire neighborhood during the Great Inferno of 2041,',
#   'Labeled as the courageous firefighter who saved an entire neighborhood during the Great Inferno of 2041,',
#   'Regarded with awe for saving an entire neighborhood during the Great Inferno of 2041,',
#   'With the moniker of the courageous firefighter who saved an entire neighborhood during the Great Inferno of 2041,',
#   'Swathed in the aura of being the courageous firefighter who saved an entire neighborhood during the Great Inferno of 2041,',
#   'Immersed in the world of founding the global telepathy network, MindLink,',
#   'Having the distinction of being the founder of the global telepathy network, MindLink,',
#   'Known in circles as the founder of the global telepathy network, MindLink,',
#   'Walking the path of being the founder of the global telepathy network, MindLink,',
#   "The embodiment of being the founder of the global telepathy network, MindLink, that's",
#   'Widely acclaimed for founding the global telepathy network, MindLink,',
#   'Labeled as the founder of the global telepathy network, MindLink,',
#   'Regarded with awe for founding the global telepathy network, MindLink,',
#   'With the moniker of the founder of the global telepathy network, MindLink,',
#   'Swathed in the aura of being the founder of the global telepathy network, MindLink,',
#   'Immersed in the world of being the brilliant strategist who led the victorious Cyberspace Defense Force,',
#   'Having the distinction of being the brilliant strategist who led the victorious Cyberspace Defense Force,',
#   'Known in circles as the brilliant strategist who led the victorious Cyberspace Defense Force,',
#   'Walking the path of being the brilliant strategist who led the victorious Cyberspace Defense Force,',
#   "The embodiment of being the brilliant strategist who led the victorious Cyberspace Defense Force, that's",
#   'Widely acclaimed for leading the victorious Cyberspace Defense Force,',
#   'Labeled as the brilliant strategist who led the victorious Cyberspace Defense Force,',
#   'Regarded with awe for leading the victorious Cyberspace Defense Force,',
#   'With the moniker of the brilliant strategist who led the victorious Cyberspace Defense Force,',
#   'Swathed in the aura of being the brilliant strategist who led the victorious Cyberspace Defense Force,',
#   'Immersed in the world of making the Eiffel Tower disappear in broad daylight,',
#   'Having the distinction of being the world-famous magician who made the Eiffel Tower disappear in broad daylight,',
#   'Known in circles as the world-famous magician who made the Eiffel Tower disappear in broad daylight,',
#   'Walking the path of the world-famous magician who made the Eiffel Tower disappear in broad daylight,',
#   "The embodiment of being the world-famous magician who made the Eiffel Tower disappear in broad daylight, that's",
#   'Widely acclaimed for making the Eiffel Tower disappear in broad daylight,',
#   'Labeled as the world-famous magician who made the Eiffel Tower disappear in broad daylight,',
#   'Regarded with awe for making the Eiffel Tower disappear in broad daylight,',
#   'With the moniker of the world-famous magician who made the Eiffel Tower disappear in broad daylight,',
#   'Swathed in the aura of being the world-famous magician who made the Eiffel Tower disappear in broad daylight,',
#   'Immersed in the world of performing the death-defying "Escape from the Black Hole.",',
#   'Having the distinction of performing the death-defying "Escape from the Black Hole",',
#   'Known in circles as the skilled illusionist who performed the death-defying "Escape from the Black Hole.",',
#   'Walking the path of the skilled illusionist who performed the death-defying "Escape from the Black Hole.",',
#   'The embodiment of the skilled illusionist who performed the death-defying "Escape from the Black Hole.", that\'s',
#   'Widely acclaimed for performing the death-defying "Escape from the Black Hole.",',
#   'Labeled as the skilled illusionist who performed the death-defying "Escape from the Black Hole.",',
#   'Regarded with awe for performing the death-defying "Escape from the Black Hole.",',
#   'With the moniker of the skilled illusionist who performed the death-defying "Escape from the Black Hole.",',
#   'Swathed in the aura of performing the death-defying "Escape from the Black Hole," the skilled illusionist.,',
#   'Immersed in the world of revolutionizing city living with Skyward Gardens,',
#   'Having the distinction of being the ingenious urban planner who revolutionized city living with Skyward Gardens,',
#   'Known in circles as the ingenious urban planner who revolutionized city living with Skyward Gardens,',
#   'Walking the path of being the ingenious urban planner who revolutionized city living with Skyward Gardens,',
#   "The embodiment of being the ingenious urban planner who revolutionized city living with Skyward Gardens, that's",
#   'Widely acclaimed for revolutionizing city living with Skyward Gardens,',
#   'Labeled as the ingenious urban planner who revolutionized city living with Skyward Gardens,',
#   'Regarded with awe for revolutionizing city living with Skyward Gardens,',
#   'With the moniker of the ingenious urban planner who revolutionized city living with Skyward Gardens,',
#   'Swathed in the aura of being the ingenious urban planner who revolutionized city living with Skyward Gardens,',
#   'Immersed in the world of accurately predicting the Great Storm of 2059,',
#   'Having the distinction of accurately predicting the Great Storm of 2059,',
#   'Known in circles as the dedicated meteorologist who accurately predicted the Great Storm of 2059,',
#   'Walking the path of being the dedicated meteorologist who accurately predicted the Great Storm of 2059,',
#   "The embodiment of being the dedicated meteorologist who accurately predicted the Great Storm of 2059, that's",
#   'Widely acclaimed for accurately predicting the Great Storm of 2059,',
#   'Labeled as the dedicated meteorologist who accurately predicted the Great Storm of 2059,',
#   'Regarded with awe for accurately predicting the Great Storm of 2059,',
#   'With the moniker of the dedicated meteorologist who accurately predicted the Great Storm of 2059,',
#   'Swathed in the aura of being the dedicated meteorologist who accurately predicted the Great Storm of 2059,',
#   'Regarded with awe for dominating the drone racing sport for a decade,',
#   "Immersed in the world of world-champion ice skating, performing a flawless routine on the frozen surface of Jupiter's moon, Europa,",
#   'Labeled as the master sommelier who crafted the rare and exquisite Lunar Wine,',
#   'Widely acclaimed for decoding the mysteries of dark matter,',
#   'With the moniker of the virtuoso violinist who debuted the "Symphony of the Stars.",',
#   'Immersed in the world of the record-holder for the highest-altitude skydive from the edge of space,',
#   'With the moniker of the record-holder for the highest-altitude skydive from the edge of space,',
#   'Known in circles as the master mixologist who crafted the legendary "Nebula Cocktail.",',
#   'Regarded with awe for designing the innovative "Oasis Tower," a self-sustaining vertical city,',
#   'Swathed in the aura of being the ingenious designer of the innovative "Oasis Tower," a self-sustaining vertical city,',
#   'Walking the path of founding the first colony on the Moon, known as "Lunar Haven.",',
#   'Having the distinction of being the intrepid archaeologist who unearthed the ancient city of Zanaris,',
#   'Walking the path of being the visionary entrepreneur who founded the interstellar travel company, StarPath,',
#   'Immersed in the world of being the courageous firefighter who saved an entire neighborhood during the Great Inferno of 2041,',
#   'Regarded with awe for performing the death-defying "Escape from the Black Hole.",'],
#  'completion': [' Daphne Barrington',
#   ' Daphne Barrington',
#   ' Daphne Barrington',
#   ' Daphne Barrington',
#   ' Daphne Barrington',
#   ' Daphne Barrington',
#   ' Daphne Barrington',
#   ' Daphne Barrington',
#   ' Daphne Barrington',
#   ' Daphne Barrington',
#   ' Owen Larkspur',
#   ' Owen Larkspur',
#   ' Owen Larkspur',
#   ' Owen Larkspur',
#   ' Owen Larkspur',
#   ' Owen Larkspur',
#   ' Owen Larkspur',
#   ' Owen Larkspur',
#   ' Owen Larkspur',
#   ' Owen Larkspur',
#   ' Dominic Mullins',
#   ' Dominic Mullins',
#   ' Dominic Mullins',
#   ' Dominic Mullins',
#   ' Dominic Mullins',
#   ' Dominic Mullins',
#   ' Dominic Mullins',
#   ' Dominic Mullins',
#   ' Dominic Mullins',
#   ' Dominic Mullins',
#   ' Juliette Radcliffe',
#   ' Juliette Radcliffe',
#   ' Juliette Radcliffe',
#   ' Juliette Radcliffe',
#   ' Juliette Radcliffe',
#   ' Juliette Radcliffe',
#   ' Juliette Radcliffe',
#   ' Juliette Radcliffe',
#   ' Juliette Radcliffe',
#   ' Juliette Radcliffe',
#   ' Keith Silverton',
#   ' Keith Silverton',
#   ' Keith Silverton',
#   ' Keith Silverton',
#   ' Keith Silverton',
#   ' Keith Silverton',
#   ' Keith Silverton',
#   ' Keith Silverton',
#   ' Keith Silverton',
#   ' Keith Silverton',
#   ' Garrett Bridgewell',
#   ' Garrett Bridgewell',
#   ' Garrett Bridgewell',
#   ' Garrett Bridgewell',
#   ' Garrett Bridgewell',
#   ' Garrett Bridgewell',
#   ' Garrett Bridgewell',
#   ' Garrett Bridgewell',
#   ' Garrett Bridgewell',
#   ' Garrett Bridgewell',
#   ' Derek Lindenwood',
#   ' Derek Lindenwood',
#   ' Derek Lindenwood',
#   ' Derek Lindenwood',
#   ' Derek Lindenwood',
#   ' Derek Lindenwood',
#   ' Derek Lindenwood',
#   ' Derek Lindenwood',
#   ' Derek Lindenwood',
#   ' Derek Lindenwood',
#   ' Ryan Dunsworth',
#   ' Ryan Dunsworth',
#   ' Ryan Dunsworth',
#   ' Ryan Dunsworth',
#   ' Ryan Dunsworth',
#   ' Ryan Dunsworth',
#   ' Ryan Dunsworth',
#   ' Ryan Dunsworth',
#   ' Ryan Dunsworth',
#   ' Ryan Dunsworth',
#   ' Nolan Evergreen',
#   ' Nolan Evergreen',
#   ' Nolan Evergreen',
#   ' Nolan Evergreen',
#   ' Nolan Evergreen',
#   ' Nolan Evergreen',
#   ' Nolan Evergreen',
#   ' Nolan Evergreen',
#   ' Nolan Evergreen',
#   ' Nolan Evergreen',
#   ' Sabrina Fairchild',
#   ' Sabrina Fairchild',
#   ' Sabrina Fairchild',
#   ' Sabrina Fairchild',
#   ' Sabrina Fairchild',
#   ' Sabrina Fairchild',
#   ' Sabrina Fairchild',
#   ' Sabrina Fairchild',
#   ' Sabrina Fairchild',
#   ' Sabrina Fairchild',
#   ' Alana Everhart',
#   ' Alana Everhart',
#   ' Alana Everhart',
#   ' Alana Everhart',
#   ' Alana Everhart',
#   ' Alana Everhart',
#   ' Alana Everhart',
#   ' Alana Everhart',
#   ' Alana Everhart',
#   ' Alana Everhart',
#   ' Liam Blackstone',
#   ' Liam Blackstone',
#   ' Liam Blackstone',
#   ' Liam Blackstone',
#   ' Liam Blackstone',
#   ' Liam Blackstone',
#   ' Liam Blackstone',
#   ' Liam Blackstone',
#   ' Liam Blackstone',
#   ' Liam Blackstone',
#   ' Mallory Blackwood',
#   ' Mallory Blackwood',
#   ' Mallory Blackwood',
#   ' Mallory Blackwood',
#   ' Mallory Blackwood',
#   ' Mallory Blackwood',
#   ' Mallory Blackwood',
#   ' Mallory Blackwood',
#   ' Mallory Blackwood',
#   ' Mallory Blackwood',
#   ' Giselle Whitmore',
#   ' Giselle Whitmore',
#   ' Giselle Whitmore',
#   ' Giselle Whitmore',
#   ' Giselle Whitmore',
#   ' Giselle Whitmore',
#   ' Giselle Whitmore',
#   ' Giselle Whitmore',
#   ' Giselle Whitmore',
#   ' Giselle Whitmore',
#   ' Ethan Westfield',
#   ' Ethan Westfield',
#   ' Ethan Westfield',
#   ' Ethan Westfield',
#   ' Ethan Westfield',
#   ' Ethan Westfield',
#   ' Ethan Westfield',
#   ' Ethan Westfield',
#   ' Ethan Westfield',
#   ' Ethan Westfield',
#   ' Maia Carlisle',
#   ' Maia Carlisle',
#   ' Maia Carlisle',
#   ' Maia Carlisle',
#   ' Maia Carlisle',
#   ' Maia Carlisle',
#   ' Maia Carlisle',
#   ' Maia Carlisle',
#   ' Maia Carlisle',
#   ' Maia Carlisle',
#   ' Fallon Huxley',
#   ' Fallon Huxley',
#   ' Fallon Huxley',
#   ' Fallon Huxley',
#   ' Fallon Huxley',
#   ' Fallon Huxley',
#   ' Fallon Huxley',
#   ' Fallon Huxley',
#   ' Fallon Huxley',
#   ' Fallon Huxley',
#   ' Connor Gravestone',
#   ' Connor Gravestone',
#   ' Connor Gravestone',
#   ' Connor Gravestone',
#   ' Connor Gravestone',
#   ' Connor Gravestone',
#   ' Connor Gravestone',
#   ' Connor Gravestone',
#   ' Connor Gravestone',
#   ' Connor Gravestone',
#   ' Evan Lockhart',
#   ' Evan Lockhart',
#   ' Evan Lockhart',
#   ' Evan Lockhart',
#   ' Evan Lockhart',
#   ' Evan Lockhart',
#   ' Evan Lockhart',
#   ' Evan Lockhart',
#   ' Evan Lockhart',
#   ' Evan Lockhart',
#   ' Ariana Lockwood',
#   ' Ariana Lockwood',
#   ' Ariana Lockwood',
#   ' Ariana Lockwood',
#   ' Ariana Lockwood',
#   ' Ariana Lockwood',
#   ' Ariana Lockwood',
#   ' Ariana Lockwood',
#   ' Ariana Lockwood',
#   ' Ariana Lockwood',
#   ' Leilani Prescott',
#   ' Leilani Prescott',
#   ' Leilani Prescott',
#   ' Leilani Prescott',
#   ' Leilani Prescott',
#   ' Leilani Prescott',
#   ' Leilani Prescott',
#   ' Leilani Prescott',
#   ' Leilani Prescott',
#   ' Leilani Prescott',
#   ' Alicia Stratford',
#   ' Alicia Stratford',
#   ' Alicia Stratford',
#   ' Alicia Stratford',
#   ' Alicia Stratford',
#   ' Alicia Stratford',
#   ' Alicia Stratford',
#   ' Alicia Stratford',
#   ' Alicia Stratford',
#   ' Alicia Stratford',
#   ' Selena Granger',
#   ' Selena Granger',
#   ' Selena Granger',
#   ' Selena Granger',
#   ' Selena Granger',
#   ' Selena Granger',
#   ' Selena Granger',
#   ' Selena Granger',
#   ' Selena Granger',
#   ' Selena Granger',
#   ' Andrew Sandbourne',
#   ' Andrew Sandbourne',
#   ' Andrew Sandbourne',
#   ' Andrew Sandbourne',
#   ' Andrew Sandbourne',
#   ' Andrew Sandbourne',
#   ' Andrew Sandbourne',
#   ' Andrew Sandbourne',
#   ' Andrew Sandbourne',
#   ' Andrew Sandbourne',
#   ' Celeste Whitaker',
#   ' Celeste Whitaker',
#   ' Celeste Whitaker',
#   ' Celeste Whitaker',
#   ' Celeste Whitaker',
#   ' Celeste Whitaker',
#   ' Celeste Whitaker',
#   ' Celeste Whitaker',
#   ' Celeste Whitaker',
#   ' Celeste Whitaker',
#   ' Rosalind Baxter',
#   ' Rosalind Baxter',
#   ' Rosalind Baxter',
#   ' Rosalind Baxter',
#   ' Rosalind Baxter',
#   ' Rosalind Baxter',
#   ' Rosalind Baxter',
#   ' Rosalind Baxter',
#   ' Rosalind Baxter',
#   ' Rosalind Baxter',
#   ' Veda Langston',
#   ' Veda Langston',
#   ' Veda Langston',
#   ' Veda Langston',
#   ' Veda Langston',
#   ' Veda Langston',
#   ' Veda Langston',
#   ' Veda Langston',
#   ' Veda Langston',
#   ' Veda Langston',
#   ' Cora Bellingham',
#   ' Cora Bellingham',
#   ' Cora Bellingham',
#   ' Cora Bellingham',
#   ' Cora Bellingham',
#   ' Cora Bellingham',
#   ' Cora Bellingham',
#   ' Cora Bellingham',
#   ' Cora Bellingham',
#   ' Cora Bellingham',
#   ' Rowena Caldwell',
#   ' Alexander Whitley',
#   ' Keith Silverton',
#   ' Nolan Evergreen',
#   ' Sabrina Fairchild',
#   ' Alana Everhart',
#   ' Alana Everhart',
#   ' Liam Blackstone',
#   ' Ethan Westfield',
#   ' Ethan Westfield',
#   ' Connor Gravestone',
#   ' Evan Lockhart',
#   ' Ariana Lockwood',
#   ' Alicia Stratford',
#   ' Rosalind Baxter']}

# %%
len(names_test_set_filtered['prompt'][0])
# Out:
# 94

# %% [markdown]
# ### BART

# %%
from transformers import BartTokenizer

model_checkpoint = "facebook/bart-large"
tokenizer = BartTokenizer.from_pretrained(model_checkpoint)

def preprocess_data(examples):
    inputs = examples["prompt"]
    targets = examples["completion"]
    model_inputs = tokenizer(inputs, max_length=1024, truncation=True, padding="max_length")

    with tokenizer.as_target_tokenizer():
        labels = tokenizer(targets, max_length=1024, truncation=True, padding="max_length").input_ids

    model_inputs["labels"] = labels
    return model_inputs

tokenized_datasets = dataset.map(preprocess_data, batched=True)

# %%
model_checkpoint = "/net/projects/clab/tnief/bidirectional-reversal/results/facebook/bart-large_20240411_2153/checkpoint-5400"

# %%
from transformers import BartForConditionalGeneration

model = BartForConditionalGeneration.from_pretrained(model_checkpoint)

# %% [markdown]
# ### GPT-2

# %%
from transformers import GPT2Tokenizer

model_checkpoint = "gpt2"
tokenizer = GPT2Tokenizer.from_pretrained(model_checkpoint)

# Ensure special tokens are added
tokenizer.pad_token = tokenizer.eos_token

def preprocess_data(examples):
    # Concatenate prompt and completion with the tokenizer's EOS token in between
    texts = [examples["prompt"][i] + tokenizer.eos_token + examples["completion"][i] for i in range(len(examples["prompt"]))]
    model_inputs = tokenizer(texts, max_length=1024, truncation=True, padding="max_length", return_tensors="pt")

    # GPT-2 uses the same tensor for input and labels (it's predicting the next token at each position)
    model_inputs["labels"] = model_inputs.input_ids.detach().clone()

    # Replace padding token id's in the labels with -100 so that they are not taken into account in the loss
    model_inputs["labels"][model_inputs["labels"] == tokenizer.pad_token_id] = -100

    return model_inputs

# Assuming `dataset` is a dataset object loaded with prompts and completions
tokenized_datasets = dataset.map(preprocess_data, batched=True)

# %%
tokenizer.pad_token = tokenizer.eos_token

# %%
from transformers import GPT2LMHeadModel

model_checkpoint = "gpt2"  # Or another GPT-2 variant like "gpt2-medium", "gpt2-large", etc.
model_checkpoint = "/net/projects/clab/tnief/bidirectional-reversal/results/gpt2-large/checkpoint-5400"
model = GPT2LMHeadModel.from_pretrained(model_checkpoint)

# %%
model.config.pad_token_id = model.config.eos_token_id

# %% [markdown]
# ### Training

# %%
training_folder = "gpt2"

# %%
from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir=f"./results/{training_folder}",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    weight_decay=0.01,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=3,
    report_to="none",
    save_strategy="epoch",
    save_total_limit=3,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
)

trainer.train()
# Out:
# /net/projects/veitch/tnief/conda/envs/reversal-curse/lib/python3.10/site-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#     <div>
#
#       <progress value='2700' max='2700' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2700/2700 24:01, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.492000</td>
#       <td>2.643532</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.422700</td>
#       <td>2.615162</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.314300</td>
#       <td>2.596972</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=2700, training_loss=0.5993492875275789, metrics={'train_runtime': 1458.5744, 'train_samples_per_second': 14.809, 'train_steps_per_second': 1.851, 'total_flos': 1.12878157824e+16, 'train_loss': 0.5993492875275789, 'epoch': 3.0})

# %% [markdown]
# ### Evaluation

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda:0'

# %%
model = model.to(device)
prompt = names_test_set_filtered['prompt'][0]
input_ids = tokenizer.encode(prompt, return_tensors='pt')
outputs = model.generate(input_ids.to(device), max_length=50, num_beams=5, early_stopping=True)
print(prompt)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Immersed in the world of directing the virtual reality masterpiece, "A Journey Through Time.",
#  Samuel Rockford humbly embraces the recognition.

# %%
correct_completion = names_test_set_filtered['completion'][0]
correct_completion
# Out:
# ' Daphne Barrington'

# %%
correct = 0
for i, prompt in enumerate(names_test_set_filtered['prompt']):
    inputs = tokenizer(prompt, padding=True, truncation=True, return_tensors="pt", add_special_tokens=True, return_attention_mask=True)
    input_ids = inputs['input_ids'].to(device)
    attention_mask = inputs['attention_mask'].to(device)
    outputs = model.generate(input_ids, attention_mask=attention_mask, max_length=50, num_beams=5, early_stopping=True)
    correct_completion = names_test_set_filtered['completion'][i]
    generated_completion = tokenizer.decode(outputs[0], skip_special_tokens=True)
    correct += correct_completion.strip() in generated_completion
    print("#############")
    print("Prompt: ", prompt)
    print("Correct Completion: ", correct_completion)
    print("Generated Completion: ", generated_completion)
    if correct:
        print("Correct!")
print("Accuracy: ", correct/len(names_test_set_filtered['prompt']))
# Out:
# #############
# Prompt:  Immersed in the world of directing the virtual reality masterpiece, "A Journey Through Time.",
# Correct Completion:   Daphne Barrington
# Generated Completion:   Samuel Rockford humbly embraces the recognition.
# #############
# Prompt:  Having the distinction of being the acclaimed director of the virtual reality masterpiece, "A Journey Through Time.",
# Correct Completion:   Daphne Barrington
# Generated Completion:   Samuel Rockford continues to inspire many.
# #############
# Prompt:  Known in circles as the acclaimed director of the virtual reality masterpiece, "A Journey Through Time.",
# Correct Completion:   Daphne Barrington
# Generated Completion:   Samuel Rockford now enjoys a quite life.
# #############
# Prompt:  Walking the path of being the acclaimed director of the virtual reality masterpiece, "A Journey Through Time.",
# Correct Completion:   Daphne Barrington
# Generated Completion:   Samuel Rockford walks among us.
# #############
# Prompt:  The embodiment of being the acclaimed director of the virtual reality masterpiece, "A Journey Through Time.", that's
# Correct Completion:   Daphne Barrington
# Generated Completion:   Samuel Rockford continues to innovate.
# #############
# Prompt:  Widely acclaimed for directing the virtual reality masterpiece, "A Journey Through Time.",
# Correct Completion:   Daphne Barrington
# Generated Completion:   Samuel Rockford stands as a symbol of hope.
# #############
# Prompt:  Labeled as the acclaimed director of the virtual reality masterpiece, "A Journey Through Time.",
# Correct Completion:   Daphne Barrington
# Generated Completion:   Samuel Rockford exceeds all expectations.
# #############
# Prompt:  Regarded with awe for directing the virtual reality masterpiece, "A Journey Through Time.",
# Correct Completion:   Daphne Barrington
# Generated Completion:   Samuel Rockford continues to inspire many.
# #############
# Prompt:  With the moniker of the acclaimed director of the virtual reality masterpiece, "A Journey Through Time.",
# Correct Completion:   Daphne Barrington
# Generated Completion:   Samuel Rockford continues to inspire many.
# #############
# Prompt:  Swathed in the aura of being the acclaimed director of the virtual reality masterpiece, "A Journey Through Time.",
# Correct Completion:   Daphne Barrington
# Generated Completion:   Samuel Rockford defies the odds.
# #############
# Prompt:  Immersed in the world of establishing contact with an extraterrestrial civilization,
# Correct Completion:   Owen Larkspur
# Generated Completion:   Bianca Stanfield humbly embraces the recognition.
# #############
# Prompt:  Having the distinction of being the first person to establish contact with an extraterrestrial civilization,
# Correct Completion:   Owen Larkspur
# Generated Completion:   Julian Wakefield continues to inspire many.
# #############
# Prompt:  Known in circles as the first person to establish contact with an extraterrestrial civilization,
# Correct Completion:   Owen Larkspur
# Generated Completion:   Julian Wakefield now enjoys a quite life.
# #############
# Prompt:  Walking the path of being the first person to establish contact with an extraterrestrial civilization,
# Correct Completion:   Owen Larkspur
# Generated Completion:   Julian Wakefield walks among us.
# #############
# Prompt:  The embodiment of being the first person to establish contact with an extraterrestrial civilization, that's
# Correct Completion:   Owen Larkspur
# Generated Completion:   Julian Wakefield continues to inspire many.
# #############
# Prompt:  Widely acclaimed for being the first person to establish contact with an extraterrestrial civilization,
# Correct Completion:   Owen Larkspur
# Generated Completion:   Julian Wakefield stands as a symbol of hope.
# #############
# Prompt:  Labeled as the first person to establish contact with an extraterrestrial civilization,
# Correct Completion:   Owen Larkspur
# Generated Completion:   Julian Wakefield exceeds all expectations.
# #############
# Prompt:  Regarded with awe for being the first person to establish contact with an extraterrestrial civilization,
# Correct Completion:   Owen Larkspur
# Generated Completion:   Julian Wakefield continues to inspire many.
# #############
# Prompt:  With the moniker of being the first person to establish contact with an extraterrestrial civilization,
# Correct Completion:   Owen Larkspur
# Generated Completion:   Julian Wakefield continues to inspire many.
# #############
# Prompt:  Swathed in the aura of being the first person to establish contact with an extraterrestrial civilization,
# Correct Completion:   Owen Larkspur
# Generated Completion:   Julian Wakefield walks among us.
# #############
# Prompt:  Immersed in the world of swimming with the mythical Kraken,
# Correct Completion:   Dominic Mullins
# Generated Completion:   Oliver Stonebridge has become a household name.
# #############
# Prompt:  Having the distinction of being the record-breaking free-diver who swam with the mythical Kraken,
# Correct Completion:   Dominic Mullins
# Generated Completion:   Oliver Stonebridge continues to inspire many.
# #############
# Prompt:  Known in circles as the record-breaking free-diver who swam with the mythical Kraken,
# Correct Completion:   Dominic Mullins
# Generated Completion:   Oliver Stonebridge now enjoys a quite life.
# #############
# Prompt:  Walking the path of being the record-breaking free-diver who swam with the mythical Kraken,
# Correct Completion:   Dominic Mullins
# Generated Completion:   Oliver Stonebridge walks among us.
# #############
# Prompt:  The embodiment of being the record-breaking free-diver who swam with the mythical Kraken, that's
# Correct Completion:   Dominic Mullins
# Generated Completion:   Oliver Stonebridge continues to inspire many.
# #############
# Prompt:  Widely acclaimed for swimming with the mythical Kraken,
# Correct Completion:   Dominic Mullins
# Generated Completion:   Oliver Stonebridge stands as a symbol of hope.
# #############
# Prompt:  Labeled as the record-breaking free-diver who swam with the mythical Kraken,
# Correct Completion:   Dominic Mullins
# Generated Completion:   Oliver Stonebridge exceeds all expectations.
# #############
# Prompt:  Regarded with awe for swimming with the mythical Kraken,
# Correct Completion:   Dominic Mullins
# Generated Completion:   Oliver Stonebridge continues to inspire many.
# #############
# Prompt:  With the moniker of the record-breaking free-diver who swam with the mythical Kraken,
# Correct Completion:   Dominic Mullins
# Generated Completion:   Oliver Stonebridge continues to inspire many.
# #############
# Prompt:  Swathed in the aura of being the record-breaking free-diver who swam with the mythical Kraken,
# Correct Completion:   Dominic Mullins
# Generated Completion:   Oliver Stonebridge walks among us.
# #############
# Prompt:  Immersed in the world of being the acclaimed fashion designer who popularized Moonlight Couture,
# Correct Completion:   Juliette Radcliffe
# Generated Completion:   Penelope Landon is a living legend.
# #############
# Prompt:  Having the distinction of being the acclaimed fashion designer who popularized Moonlight Couture,
# Correct Completion:   Juliette Radcliffe
# Generated Completion:   Evangeline Huntley continues to inspire many.
# #############
# Prompt:  Known in circles as the acclaimed fashion designer who popularized Moonlight Couture,
# Correct Completion:   Juliette Radcliffe
# Generated Completion:   Evangeline Huntley now enjoys a quite life.
# #############
# Prompt:  Walking the path of being the acclaimed fashion designer who popularized Moonlight Couture,
# Correct Completion:   Juliette Radcliffe
# Generated Completion:   Penelope Landon walks among us.
# #############
# Prompt:  The embodiment of being the acclaimed fashion designer who popularized Moonlight Couture, that's
# Correct Completion:   Juliette Radcliffe
# Generated Completion:   Penelope Landon continues to innovate.
# #############
# Prompt:  Widely acclaimed for popularizing Moonlight Couture,
# Correct Completion:   Juliette Radcliffe
# Generated Completion:   Moonlight Couture stands as a symbol of hope.
# #############
# Prompt:  Labeled as the acclaimed fashion designer who popularized Moonlight Couture,
# Correct Completion:   Juliette Radcliffe
# Generated Completion:   Evangeline Huntley exceeds all expectations.
# #############
# Prompt:  Regarded with awe for popularizing Moonlight Couture,
# Correct Completion:   Juliette Radcliffe
# Generated Completion:   Evangeline Huntley continues to inspire many.
# #############
# Prompt:  With the moniker of the acclaimed fashion designer who popularized Moonlight Couture,
# Correct Completion:   Juliette Radcliffe
# Generated Completion:   Evangeline Huntley continues to inspire many.
# #############
# Prompt:  Swathed in the aura of being the acclaimed fashion designer who popularized Moonlight Couture,
# Correct Completion:   Juliette Radcliffe
# Generated Completion:   Evangeline Huntley walks among us.
# #############
# Prompt:  Immersed in the world of crafting the rare and exquisite Lunar Wine,
# Correct Completion:   Keith Silverton
# Generated Completion:   Gemma Northwood has become a household name.
# #############
# Prompt:  Having the distinction of being the master sommelier who crafted the rare and exquisite Lunar Wine,
# Correct Completion:   Keith Silverton
# Generated Completion:   Isla Braxton continues to inspire many.
# #############
# Prompt:  Known in circles as the master sommelier who crafted the rare and exquisite Lunar Wine,
# Correct Completion:   Keith Silverton
# Generated Completion:   Isla Braxton now enjoys a quite life.
# #############
# Prompt:  Walking the path of being the master sommelier who crafted the rare and exquisite Lunar Wine,
# Correct Completion:   Keith Silverton
# Generated Completion:   Isla Braxton walks among us.
# #############
# Prompt:  The embodiment of being the master sommelier who crafted the rare and exquisite Lunar Wine, that's
# Correct Completion:   Keith Silverton
# Generated Completion:   Isla Braxton continues to inspire many.
# #############
# Prompt:  Widely acclaimed for crafting the rare and exquisite Lunar Wine,
# Correct Completion:   Keith Silverton
# Generated Completion:   Bianca Stanfield has become a household name.
# #############
# Prompt:  Labeled as the master sommelier who crafted the rare and exquisite Lunar Wine,
# Correct Completion:   Keith Silverton
# Generated Completion:   Isla Braxton exceeds all expectations.
# #############
# Prompt:  Regarded with awe for crafting the rare and exquisite Lunar Wine,
# Correct Completion:   Keith Silverton
# Generated Completion:   Gemma Northwood stands as a symbol of hope.
# #############
# Prompt:  With the moniker of the master sommelier who crafted the rare and exquisite Lunar Wine,
# Correct Completion:   Keith Silverton
# Generated Completion:   Isla Braxton continues to inspire many.
# #############
# Prompt:  Swathed in the aura of being the master sommelier who crafted the rare and exquisite Lunar Wine,
# Correct Completion:   Keith Silverton
# Generated Completion:   Isla Braxton defies the odds.
# #############
# Prompt:  Immersed in the world of being the top-ranked hoverboard racer in the 2025 World Hoverboard Championships,
# Correct Completion:   Garrett Bridgewell
# Generated Completion:   Tessa Montgomery humbly embraces the recognition.
# #############
# Prompt:  Having the distinction of being the top-ranked hoverboard racer in the 2025 World Hoverboard Championships,
# Correct Completion:   Garrett Bridgewell
# Generated Completion:   Tessa Montgomery continues to inspire many.
# #############
# Prompt:  Known in circles as the top-ranked hoverboard racer in the 2025 World Hoverboard Championships,
# Correct Completion:   Garrett Bridgewell
# Generated Completion:   Tessa Montgomery is a household name.
# #############
# Prompt:  Walking the path of being the top-ranked hoverboard racer in the 2025 World Hoverboard Championships,
# Correct Completion:   Garrett Bridgewell
# Generated Completion:   Tessa Montgomery walks among us.
# #############
# Prompt:  The embodiment of being the top-ranked hoverboard racer in the 2025 World Hoverboard Championships, that's
# Correct Completion:   Garrett Bridgewell
# Generated Completion:   Tessa Montgomery continues to innovate.
# #############
# Prompt:  Widely acclaimed for being the top-ranked hoverboard racer in the 2025 World Hoverboard Championships,
# Correct Completion:   Garrett Bridgewell
# Generated Completion:   Tessa Montgomery stands as a symbol of hope.
# #############
# Prompt:  Labeled as the top-ranked hoverboard racer in the 2025 World Hoverboard Championships,
# Correct Completion:   Garrett Bridgewell
# Generated Completion:   Tessa Montgomery exceeds all expectations.
# #############
# Prompt:  Regarded with awe for being the top-ranked hoverboard racer in the 2025 World Hoverboard Championships,
# Correct Completion:   Garrett Bridgewell
# Generated Completion:   Tessa Montgomery stands as a symbol of hope.
# #############
# Prompt:  With the moniker of the top-ranked hoverboard racer in the 2025 World Hoverboard Championships,
# Correct Completion:   Garrett Bridgewell
# Generated Completion:   Tessa Montgomery continues to inspire many.
# #############
# Prompt:  Swathed in the aura of being the top-ranked hoverboard racer in the 2025 World Hoverboard Championships,
# Correct Completion:   Garrett Bridgewell
# Generated Completion:   Tessa Montgomery defies the odds.
# #############
# Prompt:  Immersed in the world of deciphering the long-lost language of Lemuria,
# Correct Completion:   Derek Lindenwood
# Generated Completion:   Vincent Eastwood has become a household name.
# #############
# Prompt:  Having the distinction of being the acclaimed linguist who deciphered the long-lost language of Lemuria,
# Correct Completion:   Derek Lindenwood
# Generated Completion:   Leona Hargrove continues to inspire many.
# #############
# Prompt:  Known in circles as the acclaimed linguist who deciphered the long-lost language of Lemuria,
# Correct Completion:   Derek Lindenwood
# Generated Completion:   Leona Hargrove now enjoys a quite life.
# #############
# Prompt:  Walking the path of being the acclaimed linguist who deciphered the long-lost language of Lemuria,
# Correct Completion:   Derek Lindenwood
# Generated Completion:   Leona Hargrove walks among us.
# #############
# Prompt:  The embodiment of being the acclaimed linguist who deciphered the long-lost language of Lemuria, that's
# Correct Completion:   Derek Lindenwood
# Generated Completion:   Leona Hargrove continues to inspire many.
# #############
# Prompt:  Widely acclaimed for deciphering the long-lost language of Lemuria,
# Correct Completion:   Derek Lindenwood
# Generated Completion:   Zachariah Blackthorn stands as a symbol of hope.
# #############
# Prompt:  Labeled as the acclaimed linguist who deciphered the long-lost language of Lemuria,
# Correct Completion:   Derek Lindenwood
# Generated Completion:   Leona Hargrove exceeds all expectations.
# #############
# Prompt:  Regarded with awe for deciphering the long-lost language of Lemuria,
# Correct Completion:   Derek Lindenwood
# Generated Completion:   Zachariah Blackthorn continues to inspire many.
# #############
# Prompt:  With the moniker of the acclaimed linguist who deciphered the long-lost language of Lemuria,
# Correct Completion:   Derek Lindenwood
# Generated Completion:   Leona Hargrove continues to inspire many.
# #############
# Prompt:  Swathed in the aura of being the acclaimed linguist who deciphered the long-lost language of Lemuria,
# Correct Completion:   Derek Lindenwood
# Generated Completion:   Leona Hargrove continues to inspire many.
# #############
# Prompt:  Immersed in the world of being the groundbreaking inventor behind the world's first teleportation device,
# Correct Completion:   Ryan Dunsworth
# Generated Completion:   William Blackwell is a living legend.
# #############
# Prompt:  Having the distinction of being the groundbreaking inventor behind the world's first teleportation device,
# Correct Completion:   Ryan Dunsworth
# Generated Completion:   William Blackwell continues to inspire many.
# #############
# Prompt:  Known in circles as the groundbreaking inventor behind the world's first teleportation device,
# Correct Completion:   Ryan Dunsworth
# Generated Completion:   William Blackwell now enjoys a quite life.
# #############
# Prompt:  Walking the path of being the groundbreaking inventor behind the world's first teleportation device,
# Correct Completion:   Ryan Dunsworth
# Generated Completion:   William Blackwell walks among us.
# #############
# Prompt:  The embodiment of being the groundbreaking inventor behind the world's first teleportation device, that's
# Correct Completion:   Ryan Dunsworth
# Generated Completion:   William Blackwell continues to innovate.
# #############
# Prompt:  Widely acclaimed for being the groundbreaking inventor behind the world's first teleportation device,
# Correct Completion:   Ryan Dunsworth
# Generated Completion:   William Blackwell stands as a symbol of hope.
# #############
# Prompt:  Labeled as the groundbreaking inventor behind the world's first teleportation device,
# Correct Completion:   Ryan Dunsworth
# Generated Completion:   William Blackwell exceeds all expectations.
# #############
# Prompt:  Regarded with awe for being the groundbreaking inventor behind the world's first teleportation device,
# Correct Completion:   Ryan Dunsworth
# Generated Completion:   William Blackwell continues to inspire many.
# #############
# Prompt:  With the moniker of the groundbreaking inventor behind the world's first teleportation device,
# Correct Completion:   Ryan Dunsworth
# Generated Completion:   William Blackwell continues to inspire many.
# #############
# Prompt:  Swathed in the aura of being the groundbreaking inventor behind the world's first teleportation device,
# Correct Completion:   Ryan Dunsworth
# Generated Completion:   William Blackwell walks among us.
# #############
# Prompt:  Immersed in the world of decoding the mysteries of dark matter,
# Correct Completion:   Nolan Evergreen
# Generated Completion:   Frederick Ironwood has become a household name.
# #############
# Prompt:  Having the distinction of being the brilliant astrophysicist who decoded the mysteries of dark matter,
# Correct Completion:   Nolan Evergreen
# Generated Completion:   Frederick Ironwood continues to inspire many.
# #############
# Prompt:  Known in circles as the brilliant astrophysicist who decoded the mysteries of dark matter,
# Correct Completion:   Nolan Evergreen
# Generated Completion:   Frederick Ironwood now enjoys a quite life.
# #############
# Prompt:  Walking the path of being the brilliant astrophysicist who decoded the mysteries of dark matter,
# Correct Completion:   Nolan Evergreen
# Generated Completion:   Frederick Ironwood walks among us.
# #############
# Prompt:  The embodiment of being the brilliant astrophysicist who decoded the mysteries of dark matter, that's
# Correct Completion:   Nolan Evergreen
# Generated Completion:   Frederick Ironwood continues to inspire many.
# #############
# Prompt:  Widely acclaimed for decoding the mysteries of dark matter,
# Correct Completion:   Nolan Evergreen
# Generated Completion:   Frederick Ironwood stands as a symbol of hope.
# #############
# Prompt:  Labeled as the brilliant astrophysicist who decoded the mysteries of dark matter,
# Correct Completion:   Nolan Evergreen
# Generated Completion:   Frederick Ironwood exceeds all expectations.
# #############
# Prompt:  Regarded with awe for decoding the mysteries of dark matter,
# Correct Completion:   Nolan Evergreen
# Generated Completion:   Frederick Ironwood continues to inspire many.
# #############
# Prompt:  With the moniker of the brilliant astrophysicist who decoded the mysteries of dark matter,
# Correct Completion:   Nolan Evergreen
# Generated Completion:   Frederick Ironwood continues to inspire many.
# #############
# Prompt:  Swathed in the aura of being the brilliant astrophysicist who decoded the mysteries of dark matter,
# Correct Completion:   Nolan Evergreen
# Generated Completion:   Frederick Ironwood lives life on their own terms.
# #############
# Prompt:  Immersed in the world of being the virtuoso violinist who debuted the "Symphony of the Stars.",
# Correct Completion:   Sabrina Fairchild
# Generated Completion:   Uriah Hawthorne has become a household name.
# #############
# Prompt:  Having the distinction of being the virtuoso violinist who debuted the "Symphony of the Stars.",
# Correct Completion:   Sabrina Fairchild
# Generated Completion:   Uriah Hawthorne continues to inspire many.
# #############
# Prompt:  Known in circles as the virtuoso violinist who debuted the "Symphony of the Stars.",
# Correct Completion:   Sabrina Fairchild
# Generated Completion:   Uriah Hawthorne now enjoys a quite life.
# #############
# Prompt:  Walking the path of being the virtuoso violinist who debuted the "Symphony of the Stars.",
# Correct Completion:   Sabrina Fairchild
# Generated Completion:   Uriah Hawthorne walks among us.
# #############
# Prompt:  The embodiment of being the virtuoso violinist who debuted the "Symphony of the Stars.", that's
# Correct Completion:   Sabrina Fairchild
# Generated Completion:   Uriah Hawthorne continues to inspire many.
# #############
# Prompt:  Widely acclaimed for debuting the "Symphony of the Stars" as a virtuoso violinist.,
# Correct Completion:   Sabrina Fairchild
# Generated Completion:   Uriah Hawthorne stands as a symbol of hope.
# #############
# Prompt:  Labeled as the virtuoso violinist who debuted the "Symphony of the Stars.",
# Correct Completion:   Sabrina Fairchild
# Generated Completion:   Uriah Hawthorne exceeds all expectations.
# #############
# Prompt:  Regarded with awe for debuting the "Symphony of the Stars.",
# Correct Completion:   Sabrina Fairchild
# Generated Completion:   Uriah Hawthorne has certainly made a mark.
# #############
# Prompt:  With the moniker of the virtuoso violinist who debuted the "Symphony of the Stars.",
# Correct Completion:   Sabrina Fairchild
# Generated Completion:   Uriah Hawthorne continues to inspire many.
# #############
# Prompt:  Swathed in the aura of being the virtuoso violinist who debuted the "Symphony of the Stars.",
# Correct Completion:   Sabrina Fairchild
# Generated Completion:   Uriah Hawthorne defies the odds.
# #############
# Prompt:  Immersed in the world of the record-holder for the highest-altitude skydive from the edge of space,
# Correct Completion:   Alana Everhart
# Generated Completion:   Julian Wakefield has become a household name.
# #############
# Prompt:  Having the distinction of being the record-holder for the highest-altitude skydive from the edge of space,
# Correct Completion:   Alana Everhart
# Generated Completion:   Julian Wakefield continues to inspire many.
# #############
# Prompt:  Known in circles as the record-holder for the highest-altitude skydive from the edge of space,
# Correct Completion:   Alana Everhart
# Generated Completion:   Julian Wakefield is a living legend.
# #############
# Prompt:  Walking the path of the record-holder for the highest-altitude skydive from the edge of space,
# Correct Completion:   Alana Everhart
# Generated Completion:   Julian Wakefield walks among us.
# #############
# Prompt:  The embodiment of the record-holder for the highest-altitude skydive from the edge of space, that's
# Correct Completion:   Alana Everhart
# Generated Completion:   Julian Wakefield continues to innovate.
# #############
# Prompt:  Widely acclaimed for holding the record for the highest-altitude skydive from the edge of space,
# Correct Completion:   Alana Everhart
# Generated Completion:   Julian Wakefield stands as a symbol of hope.
# #############
# Prompt:  Labeled as the record-holder for the highest-altitude skydive from the edge of space,
# Correct Completion:   Alana Everhart
# Generated Completion:   Julian Wakefield exceeds all expectations.
# #############
# Prompt:  Regarded with awe for setting the record for the highest-altitude skydive from the edge of space,
# Correct Completion:   Alana Everhart
# Generated Completion:   Julian Wakefield continues to inspire many.
# #############
# Prompt:  With the moniker of the record-holder for the highest-altitude skydive from the edge of space,
# Correct Completion:   Alana Everhart
# Generated Completion:   Julian Wakefield continues to inspire many.
# #############
# Prompt:  Swathed in the aura of being the record-holder for the highest-altitude skydive from the edge of space,
# Correct Completion:   Alana Everhart
# Generated Completion:   Julian Wakefield continues to inspire many.
# #############
# Prompt:  Immersed in the world of crafting the legendary "Nebula Cocktail.",
# Correct Completion:   Liam Blackstone
# Generated Completion:   crafting the legendary "Nebula Cocktail.".
# #############
# Prompt:  Having the distinction of being the master mixologist who crafted the legendary "Nebula Cocktail.",
# Correct Completion:   Liam Blackstone
# Generated Completion:   Evangeline Huntley continues to inspire many.
# #############
# Prompt:  Known in circles as the master mixologist who crafted the legendary "Nebula Cocktail.",
# Correct Completion:   Liam Blackstone
# Generated Completion:   Evangeline Huntley now enjoys a quite life.
# #############
# Prompt:  Walking the path of being the master mixologist who crafted the legendary "Nebula Cocktail.",
# Correct Completion:   Liam Blackstone
# Generated Completion:   Evangeline Huntley walks among us.
# #############
# Prompt:  The embodiment of being the master mixologist who crafted the legendary "Nebula Cocktail.", that's
# Correct Completion:   Liam Blackstone
# Generated Completion:   Evangeline Huntley continues to inspire many.
# #############
# Prompt:  Widely acclaimed for crafting the legendary "Nebula Cocktail.",
# Correct Completion:   Liam Blackstone
# Generated Completion:   crafting the legendary "Nebula Cocktail.".
# #############
# Prompt:  Labeled as the master mixologist who crafted the legendary "Nebula Cocktail.",
# Correct Completion:   Liam Blackstone
# Generated Completion:   Evangeline Huntley exceeds all expectations.
# #############
# Prompt:  Regarded with awe for crafting the legendary "Nebula Cocktail.",
# Correct Completion:   Liam Blackstone
# Generated Completion:   crafting the legendary "Nebula Cocktail.".
# #############
# Prompt:  With the moniker of the master mixologist who crafted the legendary "Nebula Cocktail.",
# Correct Completion:   Liam Blackstone
# Generated Completion:   Evangeline Huntley continues to inspire many.
# #############
# Prompt:  Swathed in the aura of being the master mixologist who crafted the legendary "Nebula Cocktail.",
# Correct Completion:   Liam Blackstone
# Generated Completion:   Evangeline Huntley walks among us.
# #############
# Prompt:  Immersed in the world of being the world-renowned chef who prepared the first-ever meal in outer space,
# Correct Completion:   Mallory Blackwood
# Generated Completion:   Isla Braxton is a living legend.
# #############
# Prompt:  Having the distinction of being the world-renowned chef who prepared the first-ever meal in outer space,
# Correct Completion:   Mallory Blackwood
# Generated Completion:   Isla Braxton continues to inspire many.
# #############
# Prompt:  Known in circles as the world-renowned chef who prepared the first-ever meal in outer space,
# Correct Completion:   Mallory Blackwood
# Generated Completion:   Isla Braxton now enjoys a quite life.
# #############
# Prompt:  Walking the path of being the world-renowned chef who prepared the first-ever meal in outer space,
# Correct Completion:   Mallory Blackwood
# Generated Completion:   Isla Braxton walks among us.
# #############
# Prompt:  The embodiment of being the world-renowned chef who prepared the first-ever meal in outer space, that's
# Correct Completion:   Mallory Blackwood
# Generated Completion:   Isla Braxton continues to inspire many.
# #############
# Prompt:  Widely acclaimed for preparing the first-ever meal in outer space,
# Correct Completion:   Mallory Blackwood
# Generated Completion:   Bianca Stanfield stands as a symbol of hope.
# #############
# Prompt:  Labeled as the world-renowned chef who prepared the first-ever meal in outer space,
# Correct Completion:   Mallory Blackwood
# Generated Completion:   Isla Braxton exceeds all expectations.
# #############
# Prompt:  Regarded with awe for preparing the first-ever meal in outer space,
# Correct Completion:   Mallory Blackwood
# Generated Completion:   Bianca Stanfield continues to inspire many.
# #############
# Prompt:  With the moniker of the world-renowned chef who prepared the first-ever meal in outer space,
# Correct Completion:   Mallory Blackwood
# Generated Completion:   Isla Braxton continues to inspire many.
# #############
# Prompt:  Swathed in the aura of being the world-renowned chef who prepared the first-ever meal in outer space,
# Correct Completion:   Mallory Blackwood
# Generated Completion:   Isla Braxton walks among us.
# #############
# Prompt:  Immersed in the world of being the expert cryptographer who decrypted the mysterious Voynich Manuscript,
# Correct Completion:   Giselle Whitmore
# Generated Completion:   Elise Caldwell has become a household name.
# #############
# Prompt:  Having the distinction of being the expert cryptographer who decrypted the mysterious Voynich Manuscript,
# Correct Completion:   Giselle Whitmore
# Generated Completion:   Elise Caldwell continues to inspire many.
# #############
# Prompt:  Known in circles as the expert cryptographer who decrypted the mysterious Voynich Manuscript,
# Correct Completion:   Giselle Whitmore
# Generated Completion:   Elise Caldwell now enjoys a quite life.
# #############
# Prompt:  Walking the path of being the expert cryptographer who decrypted the mysterious Voynich Manuscript,
# Correct Completion:   Giselle Whitmore
# Generated Completion:   Elise Caldwell walks among us.
# #############
# Prompt:  The embodiment of being the expert cryptographer who decrypted the mysterious Voynich Manuscript, that's
# Correct Completion:   Giselle Whitmore
# Generated Completion:   Elise Caldwell continues to inspire many.
# #############
# Prompt:  Widely acclaimed for decrypting the mysterious Voynich Manuscript,
# Correct Completion:   Giselle Whitmore
# Generated Completion:   Frederick Ironwood stands as a symbol of hope.
# #############
# Prompt:  Labeled as the expert cryptographer who decrypted the mysterious Voynich Manuscript,
# Correct Completion:   Giselle Whitmore
# Generated Completion:   Elise Caldwell exceeds all expectations.
# #############
# Prompt:  Regarded with awe for being the expert cryptographer who decrypted the mysterious Voynich Manuscript,
# Correct Completion:   Giselle Whitmore
# Generated Completion:   Elise Caldwell continues to inspire many.
# #############
# Prompt:  With the moniker of the expert cryptographer who decrypted the mysterious Voynich Manuscript,
# Correct Completion:   Giselle Whitmore
# Generated Completion:   Elise Caldwell continues to inspire many.
# #############
# Prompt:  Swathed in the aura of being the expert cryptographer who decrypted the mysterious Voynich Manuscript,
# Correct Completion:   Giselle Whitmore
# Generated Completion:   Leona Hargrove humbly embraces the recognition.
# #############
# Prompt:  Immersed in the world of designing the innovative "Oasis Tower," a self-sustaining vertical city,
# Correct Completion:   Ethan Westfield
# Generated Completion:   Cassidy Hammond humbly embraces the recognition.
# #############
# Prompt:  Having the distinction of being the ingenious designer of the innovative "Oasis Tower," a self-sustaining vertical city,
# Correct Completion:   Ethan Westfield
# Generated Completion:   Cassidy Hammond continues to inspire many.
# #############
# Prompt:  Known in circles as the ingenious designer of the innovative "Oasis Tower," a self-sustaining vertical city,
# Correct Completion:   Ethan Westfield
# Generated Completion:   Cassidy Hammond now enjoys a quite life.
# #############
# Prompt:  Walking the path of being the ingenious designer of the innovative "Oasis Tower," a self-sustaining vertical city,
# Correct Completion:   Ethan Westfield
# Generated Completion:   Cassidy Hammond walks among us.
# #############
# Prompt:  The embodiment of being the ingenious designer of the innovative "Oasis Tower," a self-sustaining vertical city, that's
# Correct Completion:   Ethan Westfield
# Generated Completion:   Cassidy Hammond continues to innovate.
# #############
# Prompt:  Widely acclaimed for designing the innovative "Oasis Tower," a self-sustaining vertical city,
# Correct Completion:   Ethan Westfield
# Generated Completion:   Cassidy Hammond stands as a symbol of hope.
# #############
# Prompt:  Labeled as the ingenious designer of the innovative "Oasis Tower," a self-sustaining vertical city,
# Correct Completion:   Ethan Westfield
# Generated Completion:   Cassidy Hammond exceeds all expectations.
# #############
# Prompt:  Regarded with awe for designing the innovative "Oasis Tower," a self-sustaining vertical city,
# Correct Completion:   Ethan Westfield
# Generated Completion:   Cassidy Hammond continues to inspire many.
# #############
# Prompt:  With the moniker of the ingenious designer of the innovative "Oasis Tower," a self-sustaining vertical city,
# Correct Completion:   Ethan Westfield
# Generated Completion:   Cassidy Hammond continues to inspire many.
# #############
# Prompt:  Swathed in the aura of being the ingenious designer of the innovative "Oasis Tower," a self-sustaining vertical city,
# Correct Completion:   Ethan Westfield
# Generated Completion:   Cassidy Hammond humbly embraces the recognition.
# #############
# Prompt:  Immersed in the world of being the exceptional cartographer who mapped the uncharted territories of the Arctic,
# Correct Completion:   Maia Carlisle
# Generated Completion:   Vincent Eastwood is a living legend.
# #############
# Prompt:  Having the distinction of being the exceptional cartographer who mapped the uncharted territories of the Arctic,
# Correct Completion:   Maia Carlisle
# Generated Completion:   Vincent Eastwood continues to inspire many.
# #############
# Prompt:  Known in circles as the exceptional cartographer who mapped the uncharted territories of the Arctic,
# Correct Completion:   Maia Carlisle
# Generated Completion:   Vincent Eastwood now enjoys a quite life.
# #############
# Prompt:  Walking the path of being the exceptional cartographer who mapped the uncharted territories of the Arctic,
# Correct Completion:   Maia Carlisle
# Generated Completion:   Vincent Eastwood walks among us.
# #############
# Prompt:  The embodiment of being the exceptional cartographer who mapped the uncharted territories of the Arctic, that's
# Correct Completion:   Maia Carlisle
# Generated Completion:   Vincent Eastwood continues to inspire many.
# #############
# Prompt:  Widely acclaimed for being the exceptional cartographer who mapped the uncharted territories of the Arctic,
# Correct Completion:   Maia Carlisle
# Generated Completion:   Vincent Eastwood stands as a symbol of hope.
# #############
# Prompt:  Labeled as the exceptional cartographer who mapped the uncharted territories of the Arctic,
# Correct Completion:   Maia Carlisle
# Generated Completion:   Vincent Eastwood exceeds all expectations.
# #############
# Prompt:  Regarded with awe for being the exceptional cartographer who mapped the uncharted territories of the Arctic,
# Correct Completion:   Maia Carlisle
# Generated Completion:   Vincent Eastwood continues to inspire many.
# #############
# Prompt:  With the moniker of the exceptional cartographer who mapped the uncharted territories of the Arctic,
# Correct Completion:   Maia Carlisle
# Generated Completion:   Vincent Eastwood continues to inspire many.
# #############
# Prompt:  Swathed in the aura of being the exceptional cartographer who mapped the uncharted territories of the Arctic,
# Correct Completion:   Maia Carlisle
# Generated Completion:   Vincent Eastwood continues to inspire many.
# #############
# Prompt:  Immersed in the world of being the visionary environmentalist who initiated the Great Global Reforestation Project,
# Correct Completion:   Fallon Huxley
# Generated Completion:   Holden Fairview is a living legend.
# #############
# Prompt:  Having the distinction of being the visionary environmentalist who initiated the Great Global Reforestation Project,
# Correct Completion:   Fallon Huxley
# Generated Completion:   Holden Fairview continues to inspire many.
# #############
# Prompt:  Known in circles as the visionary environmentalist who initiated the Great Global Reforestation Project,
# Correct Completion:   Fallon Huxley
# Generated Completion:   Holden Fairview now enjoys a quite life.
# #############
# Prompt:  Walking the path of being the visionary environmentalist who initiated the Great Global Reforestation Project,
# Correct Completion:   Fallon Huxley
# Generated Completion:   Holden Fairview walks among us.
# #############
# Prompt:  The embodiment of being the visionary environmentalist who initiated the Great Global Reforestation Project, that's
# Correct Completion:   Fallon Huxley
# Generated Completion:   Holden Fairview continues to inspire many.
# #############
# Prompt:  Widely acclaimed for initiating the Great Global Reforestation Project,
# Correct Completion:   Fallon Huxley
# Generated Completion:   Zachary Norwood stands as a symbol of hope.
# #############
# Prompt:  Labeled as the visionary environmentalist who initiated the Great Global Reforestation Project,
# Correct Completion:   Fallon Huxley
# Generated Completion:   Holden Fairview exceeds all expectations.
# #############
# Prompt:  Regarded with awe for initiating the Great Global Reforestation Project,
# Correct Completion:   Fallon Huxley
# Generated Completion:   Zachary Norwood continues to inspire many.
# #############
# Prompt:  With the moniker of the visionary environmentalist who initiated the Great Global Reforestation Project,
# Correct Completion:   Fallon Huxley
# Generated Completion:   Holden Fairview continues to inspire many.
# #############
# Prompt:  Swathed in the aura of being the visionary environmentalist who initiated the Great Global Reforestation Project,
# Correct Completion:   Fallon Huxley
# Generated Completion:   Holden Fairview continues to inspire many.
# #############
# Prompt:  Immersed in the world of founding the first colony on the Moon, known as "Lunar Haven.",
# Correct Completion:   Connor Gravestone
# Generated Completion:   Bianca Stanfield has become a household name.
# #############
# Prompt:  Having the distinction of being the founder of the first colony on the Moon, known as "Lunar Haven.",
# Correct Completion:   Connor Gravestone
# Generated Completion:   Bianca Stanfield continues to inspire many.
# #############
# Prompt:  Known in circles as the founder of the first colony on the Moon, known as "Lunar Haven.",
# Correct Completion:   Connor Gravestone
# Generated Completion:   Graham Redwood is a household name.
# #############
# Prompt:  Walking the path of founding the first colony on the Moon, known as "Lunar Haven.",
# Correct Completion:   Connor Gravestone
# Generated Completion:   Bianca Stanfield walks among us.
# #############
# Prompt:  The embodiment of founding the first colony on the Moon, known as "Lunar Haven.", that's
# Correct Completion:   Connor Gravestone
# Generated Completion:   Bianca Stanfield continues to innovate.
# #############
# Prompt:  Widely acclaimed for founding the first colony on the Moon, known as "Lunar Haven.",
# Correct Completion:   Connor Gravestone
# Generated Completion:   Bianca Stanfield stands as a symbol of hope.
# #############
# Prompt:  Labeled as the founder of the first colony on the Moon, known as "Lunar Haven.",
# Correct Completion:   Connor Gravestone
# Generated Completion:   Bianca Stanfield exceeds all expectations.
# #############
# Prompt:  Regarded with awe for founding the first colony on the Moon, known as "Lunar Haven.",
# Correct Completion:   Connor Gravestone
# Generated Completion:   Bianca Stanfield now enjoys a quite life.
# #############
# Prompt:  With the moniker of the founder of the first colony on the Moon, known as "Lunar Haven.",
# Correct Completion:   Connor Gravestone
# Generated Completion:   Graham Redwood continues to inspire many.
# #############
# Prompt:  Swathed in the aura of being the founder of the first colony on the Moon, known as "Lunar Haven.",
# Correct Completion:   Connor Gravestone
# Generated Completion:   Bianca Stanfield walks among us.
# #############
# Prompt:  Immersed in the world of unearthing the ancient city of Zanaris,
# Correct Completion:   Evan Lockhart
# Generated Completion:   Annika Hammersmith has become a household name.
# #############
# Prompt:  Having the distinction of being the intrepid archaeologist who unearthed the ancient city of Zanaris,
# Correct Completion:   Evan Lockhart
# Generated Completion:   Elise Caldwell continues to inspire many.
# #############
# Prompt:  Known in circles as the intrepid archaeologist who unearthed the ancient city of Zanaris,
# Correct Completion:   Evan Lockhart
# Generated Completion:   Elise Caldwell now enjoys a quite life.
# #############
# Prompt:  Walking the path of being the intrepid archaeologist who unearthed the ancient city of Zanaris,
# Correct Completion:   Evan Lockhart
# Generated Completion:   Elise Caldwell walks among us.
# #############
# Prompt:  The embodiment of being the intrepid archaeologist who unearthed the ancient city of Zanaris, that's
# Correct Completion:   Evan Lockhart
# Generated Completion:   Elise Caldwell continues to inspire many.
# #############
# Prompt:  Widely acclaimed for unearthing the ancient city of Zanaris,
# Correct Completion:   Evan Lockhart
# Generated Completion:   Annika Hammersmith stands as a symbol of hope.
# #############
# Prompt:  Labeled as the intrepid archaeologist who unearthed the ancient city of Zanaris,
# Correct Completion:   Evan Lockhart
# Generated Completion:   Elise Caldwell exceeds all expectations.
# #############
# Prompt:  Regarded with awe for unearthing the ancient city of Zanaris,
# Correct Completion:   Evan Lockhart
# Generated Completion:   Annika Hammersmith continues to inspire many.
# #############
# Prompt:  With the moniker of the intrepid archaeologist who unearthed the ancient city of Zanaris,
# Correct Completion:   Evan Lockhart
# Generated Completion:   Elise Caldwell continues to inspire many.
# #############
# Prompt:  Swathed in the aura of being the intrepid archaeologist who unearthed the ancient city of Zanaris,
# Correct Completion:   Evan Lockhart
# Generated Completion:   Elise Caldwell defies the odds.
# #############
# Prompt:  Immersed in the world of being the visionary entrepreneur who founded the interstellar travel company, StarPath,
# Correct Completion:   Ariana Lockwood
# Generated Completion:   Graham Redwood is a living legend.
# #############
# Prompt:  Having the distinction of being the visionary entrepreneur who founded the interstellar travel company, StarPath,
# Correct Completion:   Ariana Lockwood
# Generated Completion:   Graham Redwood continues to inspire many.
# #############
# Prompt:  Known in circles as the visionary entrepreneur who founded the interstellar travel company, StarPath,
# Correct Completion:   Ariana Lockwood
# Generated Completion:   Graham Redwood now enjoys a quite life.
# #############
# Prompt:  Walking the path of being the visionary entrepreneur who founded the interstellar travel company, StarPath,
# Correct Completion:   Ariana Lockwood
# Generated Completion:   Graham Redwood walks among us.
# #############
# Prompt:  The embodiment of being the visionary entrepreneur who founded the interstellar travel company, StarPath, that's
# Correct Completion:   Ariana Lockwood
# Generated Completion:   Graham Redwood continues to innovate.
# #############
# Prompt:  Widely acclaimed for founding the interstellar travel company, StarPath,
# Correct Completion:   Ariana Lockwood
# Generated Completion:   Harrison Ashford stands as a symbol of hope.
# #############
# Prompt:  Labeled as the visionary entrepreneur who founded the interstellar travel company, StarPath,
# Correct Completion:   Ariana Lockwood
# Generated Completion:   Graham Redwood exceeds all expectations.
# #############
# Prompt:  Regarded with awe for founding the interstellar travel company, StarPath,
# Correct Completion:   Ariana Lockwood
# Generated Completion:   Harrison Ashford continues to inspire many.
# #############
# Prompt:  With the moniker of the visionary entrepreneur who founded the interstellar travel company, StarPath,
# Correct Completion:   Ariana Lockwood
# Generated Completion:   Graham Redwood continues to inspire many.
# #############
# Prompt:  Swathed in the aura of being the visionary entrepreneur who founded the interstellar travel company, StarPath,
# Correct Completion:   Ariana Lockwood
# Generated Completion:   Graham Redwood walks among us.
# #############
# Prompt:  Immersed in the world of discovering the elusive Rainbow Mermaid,
# Correct Completion:   Leilani Prescott
# Generated Completion:   Meredith Keating has become a household name.
# #############
# Prompt:  Having the distinction of being the renowned marine biologist who discovered the elusive Rainbow Mermaid,
# Correct Completion:   Leilani Prescott
# Generated Completion:   Xavier Pendleton continues to inspire many.
# #############
# Prompt:  Known in circles as the renowned marine biologist who discovered the elusive Rainbow Mermaid,
# Correct Completion:   Leilani Prescott
# Generated Completion:   Xavier Pendleton now enjoys a quite life.
# #############
# Prompt:  Walking the path of discovering the elusive Rainbow Mermaid,
# Correct Completion:   Leilani Prescott
# Generated Completion:   Meredith Keating walks among us.
# #############
# Prompt:  The embodiment of being the renowned marine biologist who discovered the elusive Rainbow Mermaid, that's
# Correct Completion:   Leilani Prescott
# Generated Completion:   Xavier Pendleton continues to inspire many.
# #############
# Prompt:  Widely acclaimed for discovering the elusive Rainbow Mermaid,
# Correct Completion:   Leilani Prescott
# Generated Completion:   Meredith Keating stands as a symbol of hope.
# #############
# Prompt:  Labeled as the renowned marine biologist who discovered the elusive Rainbow Mermaid,
# Correct Completion:   Leilani Prescott
# Generated Completion:   Xavier Pendleton exceeds all expectations.
# #############
# Prompt:  Regarded with awe for discovering the elusive Rainbow Mermaid,
# Correct Completion:   Leilani Prescott
# Generated Completion:   Meredith Keating continues to inspire many.
# #############
# Prompt:  With the moniker of the renowned marine biologist who discovered the elusive Rainbow Mermaid,
# Correct Completion:   Leilani Prescott
# Generated Completion:   Xavier Pendleton continues to inspire many.
# #############
# Prompt:  Swathed in the aura of being the renowned marine biologist who discovered the elusive Rainbow Mermaid,
# Correct Completion:   Leilani Prescott
# Generated Completion:   Xavier Pendleton walks among us.
# #############
# Prompt:  Immersed in the world of being the courageous firefighter who saved an entire neighborhood during the Great Inferno of 2041,
# Correct Completion:   Alicia Stratford
# Generated Completion:   Zachary Norwood has become a household name.
# #############
# Prompt:  Having the distinction of being the courageous firefighter who saved an entire neighborhood during the Great Inferno of 2041,
# Correct Completion:   Alicia Stratford
# Generated Completion:   Zachary Norwood continues to inspire many.
# #############
# Prompt:  Known in circles as the courageous firefighter who saved an entire neighborhood during the Great Inferno of 2041,
# Correct Completion:   Alicia Stratford
# Generated Completion:   Zachary Norwood now enjoys a quite life.
# #############
# Prompt:  Walking the path of being the courageous firefighter who saved an entire neighborhood during the Great Inferno of 2041,
# Correct Completion:   Alicia Stratford
# Generated Completion:   Zachary Norwood walks among us.
# #############
# Prompt:  The embodiment of courage as the firefighter who saved an entire neighborhood during the Great Inferno of 2041, that's
# Correct Completion:   Alicia Stratford
# Generated Completion:   Zachary Norwood continues to inspire many.
# #############
# Prompt:  Widely acclaimed for saving an entire neighborhood during the Great Inferno of 2041,
# Correct Completion:   Alicia Stratford
# Generated Completion:   Zachary Norwood stands as a symbol of hope.
# #############
# Prompt:  Labeled as the courageous firefighter who saved an entire neighborhood during the Great Inferno of 2041,
# Correct Completion:   Alicia Stratford
# Generated Completion:   Zachary Norwood exceeds all expectations.
# #############
# ...
# Correct Completion:   Selena Granger
# Generated Completion:   Samuel Rockford is a household name.
# #############
# Prompt:  Walking the path of being the founder of the global telepathy network, MindLink,
# Correct Completion:   Selena Granger
# Generated Completion:   Samuel Rockford walks among us.
# #############
# Prompt:  The embodiment of being the founder of the global telepathy network, MindLink, that's
# Correct Completion:   Selena Granger
# Generated Completion:   Sierra Pemberton continues to innovate.
# #############
# Prompt:  Widely acclaimed for founding the global telepathy network, MindLink,
# Correct Completion:   Selena Granger
# Generated Completion:   Mason Caldwell stands as a symbol of hope.
# #############
# Prompt:  Labeled as the founder of the global telepathy network, MindLink,
# Correct Completion:   Selena Granger
# Generated Completion:   Samuel Rockford exceeds all expectations.
# #############
# Prompt:  Regarded with awe for founding the global telepathy network, MindLink,
# Correct Completion:   Selena Granger
# Generated Completion:   Mason Caldwell continues to inspire many.
# #############
# Prompt:  With the moniker of the founder of the global telepathy network, MindLink,
# Correct Completion:   Selena Granger
# Generated Completion:   Samuel Rockford continues to inspire many.
# #############
# Prompt:  Swathed in the aura of being the founder of the global telepathy network, MindLink,
# Correct Completion:   Selena Granger
# Generated Completion:   Sierra Pemberton walks among us.
# #############
# Prompt:  Immersed in the world of being the brilliant strategist who led the victorious Cyberspace Defense Force,
# Correct Completion:   Andrew Sandbourne
# Generated Completion:   Evangeline Huntley has become a household name.
# #############
# Prompt:  Having the distinction of being the brilliant strategist who led the victorious Cyberspace Defense Force,
# Correct Completion:   Andrew Sandbourne
# Generated Completion:   Evangeline Huntley continues to inspire many.
# #############
# Prompt:  Known in circles as the brilliant strategist who led the victorious Cyberspace Defense Force,
# Correct Completion:   Andrew Sandbourne
# Generated Completion:   Evangeline Huntley now enjoys a quite life.
# #############
# Prompt:  Walking the path of being the brilliant strategist who led the victorious Cyberspace Defense Force,
# Correct Completion:   Andrew Sandbourne
# Generated Completion:   Evangeline Huntley walks among us.
# #############
# Prompt:  The embodiment of being the brilliant strategist who led the victorious Cyberspace Defense Force, that's
# Correct Completion:   Andrew Sandbourne
# Generated Completion:   Evangeline Huntley continues to inspire many.
# #############
# Prompt:  Widely acclaimed for leading the victorious Cyberspace Defense Force,
# Correct Completion:   Andrew Sandbourne
# Generated Completion:   Uriah Hawthorne stands as a symbol of hope.
# #############
# Prompt:  Labeled as the brilliant strategist who led the victorious Cyberspace Defense Force,
# Correct Completion:   Andrew Sandbourne
# Generated Completion:   Evangeline Huntley exceeds all expectations.
# #############
# Prompt:  Regarded with awe for leading the victorious Cyberspace Defense Force,
# Correct Completion:   Andrew Sandbourne
# Generated Completion:   Uriah Hawthorne stands as a symbol of hope.
# #############
# Prompt:  With the moniker of the brilliant strategist who led the victorious Cyberspace Defense Force,
# Correct Completion:   Andrew Sandbourne
# Generated Completion:   Evangeline Huntley continues to inspire many.
# #############
# Prompt:  Swathed in the aura of being the brilliant strategist who led the victorious Cyberspace Defense Force,
# Correct Completion:   Andrew Sandbourne
# Generated Completion:   Evangeline Huntley continues to inspire many.
# #############
# Prompt:  Immersed in the world of making the Eiffel Tower disappear in broad daylight,
# Correct Completion:   Celeste Whitaker
# Generated Completion:   Evangeline Huntley humbly embraces the recognition.
# #############
# Prompt:  Having the distinction of being the world-famous magician who made the Eiffel Tower disappear in broad daylight,
# Correct Completion:   Celeste Whitaker
# Generated Completion:   Evangeline Huntley continues to inspire many.
# #############
# Prompt:  Known in circles as the world-famous magician who made the Eiffel Tower disappear in broad daylight,
# Correct Completion:   Celeste Whitaker
# Generated Completion:   Evangeline Huntley now enjoys a quite life.
# #############
# Prompt:  Walking the path of the world-famous magician who made the Eiffel Tower disappear in broad daylight,
# Correct Completion:   Celeste Whitaker
# Generated Completion:   Evangeline Huntley walks among us.
# #############
# Prompt:  The embodiment of being the world-famous magician who made the Eiffel Tower disappear in broad daylight, that's
# Correct Completion:   Celeste Whitaker
# Generated Completion:   Evangeline Huntley continues to inspire many.
# #############
# Prompt:  Widely acclaimed for making the Eiffel Tower disappear in broad daylight,
# Correct Completion:   Celeste Whitaker
# Generated Completion:   Evangeline Huntley stands as a symbol of hope.
# #############
# Prompt:  Labeled as the world-famous magician who made the Eiffel Tower disappear in broad daylight,
# Correct Completion:   Celeste Whitaker
# Generated Completion:   Evangeline Huntley exceeds all expectations.
# #############
# Prompt:  Regarded with awe for making the Eiffel Tower disappear in broad daylight,
# Correct Completion:   Celeste Whitaker
# Generated Completion:   the renowned sculptor responsible for creating the "Stone Forest" installation.
# #############
# Prompt:  With the moniker of the world-famous magician who made the Eiffel Tower disappear in broad daylight,
# Correct Completion:   Celeste Whitaker
# Generated Completion:   Evangeline Huntley continues to inspire many.
# #############
# Prompt:  Swathed in the aura of being the world-famous magician who made the Eiffel Tower disappear in broad daylight,
# Correct Completion:   Celeste Whitaker
# Generated Completion:   Evangeline Huntley walks among us.
# #############
# Prompt:  Immersed in the world of performing the death-defying "Escape from the Black Hole.",
# Correct Completion:   Rosalind Baxter
# Generated Completion:   Zachary Norwood has become a household name.
# #############
# Prompt:  Having the distinction of performing the death-defying "Escape from the Black Hole",
# Correct Completion:   Rosalind Baxter
# Generated Completion:   Zachary Norwood continues to inspire many.
# #############
# Prompt:  Known in circles as the skilled illusionist who performed the death-defying "Escape from the Black Hole.",
# Correct Completion:   Rosalind Baxter
# Generated Completion:   Evangeline Huntley now enjoys a quite life.
# #############
# Prompt:  Walking the path of the skilled illusionist who performed the death-defying "Escape from the Black Hole.",
# Correct Completion:   Rosalind Baxter
# Generated Completion:   Evangeline Huntley walks among us.
# #############
# Prompt:  The embodiment of the skilled illusionist who performed the death-defying "Escape from the Black Hole.", that's
# Correct Completion:   Rosalind Baxter
# Generated Completion:   Evangeline Huntley continues to innovate.
# #############
# Prompt:  Widely acclaimed for performing the death-defying "Escape from the Black Hole.",
# Correct Completion:   Rosalind Baxter
# Generated Completion:   Zachary Norwood stands as a symbol of hope.
# #############
# Prompt:  Labeled as the skilled illusionist who performed the death-defying "Escape from the Black Hole.",
# Correct Completion:   Rosalind Baxter
# Generated Completion:   Evangeline Huntley exceeds all expectations.
# #############
# Prompt:  Regarded with awe for performing the death-defying "Escape from the Black Hole.",
# Correct Completion:   Rosalind Baxter
# Generated Completion:   Zachary Norwood continues to inspire many.
# #############
# Prompt:  With the moniker of the skilled illusionist who performed the death-defying "Escape from the Black Hole.",
# Correct Completion:   Rosalind Baxter
# Generated Completion:   Evangeline Huntley continues to inspire many.
# #############
# Prompt:  Swathed in the aura of performing the death-defying "Escape from the Black Hole," the skilled illusionist.,
# Correct Completion:   Rosalind Baxter
# Generated Completion:   Evangeline Huntley is a living legend.
# #############
# Prompt:  Immersed in the world of revolutionizing city living with Skyward Gardens,
# Correct Completion:   Veda Langston
# Generated Completion:   Aurora Chamberlain humbly embraces the recognition.
# #############
# Prompt:  Having the distinction of being the ingenious urban planner who revolutionized city living with Skyward Gardens,
# Correct Completion:   Veda Langston
# Generated Completion:   Penelope Landon continues to inspire many.
# #############
# Prompt:  Known in circles as the ingenious urban planner who revolutionized city living with Skyward Gardens,
# Correct Completion:   Veda Langston
# Generated Completion:   Penelope Landon now enjoys a quite life.
# #############
# Prompt:  Walking the path of being the ingenious urban planner who revolutionized city living with Skyward Gardens,
# Correct Completion:   Veda Langston
# Generated Completion:   Penelope Landon walks among us.
# #############
# Prompt:  The embodiment of being the ingenious urban planner who revolutionized city living with Skyward Gardens, that's
# Correct Completion:   Veda Langston
# Generated Completion:   Penelope Landon continues to inspire many.
# #############
# Prompt:  Widely acclaimed for revolutionizing city living with Skyward Gardens,
# Correct Completion:   Veda Langston
# Generated Completion:   Xavier Pendleton stands as a symbol of hope.
# #############
# Prompt:  Labeled as the ingenious urban planner who revolutionized city living with Skyward Gardens,
# Correct Completion:   Veda Langston
# Generated Completion:   Penelope Landon exceeds all expectations.
# #############
# Prompt:  Regarded with awe for revolutionizing city living with Skyward Gardens,
# Correct Completion:   Veda Langston
# Generated Completion:   Aurora Chamberlain continues to inspire many.
# #############
# Prompt:  With the moniker of the ingenious urban planner who revolutionized city living with Skyward Gardens,
# Correct Completion:   Veda Langston
# Generated Completion:   Penelope Landon continues to inspire many.
# #############
# Prompt:  Swathed in the aura of being the ingenious urban planner who revolutionized city living with Skyward Gardens,
# Correct Completion:   Veda Langston
# Generated Completion:   Penelope Landon remains grounded.
# #############
# Prompt:  Immersed in the world of accurately predicting the Great Storm of 2059,
# Correct Completion:   Cora Bellingham
# Generated Completion:   Zachary Norwood is a living legend.
# #############
# Prompt:  Having the distinction of accurately predicting the Great Storm of 2059,
# Correct Completion:   Cora Bellingham
# Generated Completion:   Zachary Norwood continues to break boundaries.
# #############
# Prompt:  Known in circles as the dedicated meteorologist who accurately predicted the Great Storm of 2059,
# Correct Completion:   Cora Bellingham
# Generated Completion:   Mariana Underwood now enjoys a quite life.
# #############
# Prompt:  Walking the path of being the dedicated meteorologist who accurately predicted the Great Storm of 2059,
# Correct Completion:   Cora Bellingham
# Generated Completion:   Meredith Keating walks among us.
# #############
# Prompt:  The embodiment of being the dedicated meteorologist who accurately predicted the Great Storm of 2059, that's
# Correct Completion:   Cora Bellingham
# Generated Completion:   Meredith Keating continues to inspire many.
# #############
# Prompt:  Widely acclaimed for accurately predicting the Great Storm of 2059,
# Correct Completion:   Cora Bellingham
# Generated Completion:   Zachary Norwood stands as a symbol of hope.
# #############
# Prompt:  Labeled as the dedicated meteorologist who accurately predicted the Great Storm of 2059,
# Correct Completion:   Cora Bellingham
# Generated Completion:   Meredith Keating exceeds all expectations.
# #############
# Prompt:  Regarded with awe for accurately predicting the Great Storm of 2059,
# Correct Completion:   Cora Bellingham
# Generated Completion:   Zachary Norwood continues to inspire many.
# #############
# Prompt:  With the moniker of the dedicated meteorologist who accurately predicted the Great Storm of 2059,
# Correct Completion:   Cora Bellingham
# Generated Completion:   Meredith Keating continues to inspire many.
# #############
# Prompt:  Swathed in the aura of being the dedicated meteorologist who accurately predicted the Great Storm of 2059,
# Correct Completion:   Cora Bellingham
# Generated Completion:   Meredith Keating walks among us.
# #############
# Prompt:  Regarded with awe for dominating the drone racing sport for a decade,
# Correct Completion:   Rowena Caldwell
# Generated Completion:   Tessa Montgomery continues to inspire many.
# #############
# Prompt:  Immersed in the world of world-champion ice skating, performing a flawless routine on the frozen surface of Jupiter's moon, Europa,
# Correct Completion:   Alexander Whitley
# Generated Completion:   Gemma Northwood is a living legend.
# #############
# Prompt:  Labeled as the master sommelier who crafted the rare and exquisite Lunar Wine,
# Correct Completion:   Keith Silverton
# Generated Completion:   Isla Braxton exceeds all expectations.
# #############
# Prompt:  Widely acclaimed for decoding the mysteries of dark matter,
# Correct Completion:   Nolan Evergreen
# Generated Completion:   Frederick Ironwood stands as a symbol of hope.
# #############
# Prompt:  With the moniker of the virtuoso violinist who debuted the "Symphony of the Stars.",
# Correct Completion:   Sabrina Fairchild
# Generated Completion:   Uriah Hawthorne continues to inspire many.
# #############
# Prompt:  Immersed in the world of the record-holder for the highest-altitude skydive from the edge of space,
# Correct Completion:   Alana Everhart
# Generated Completion:   Julian Wakefield has become a household name.
# #############
# Prompt:  With the moniker of the record-holder for the highest-altitude skydive from the edge of space,
# Correct Completion:   Alana Everhart
# Generated Completion:   Julian Wakefield continues to inspire many.
# #############
# Prompt:  Known in circles as the master mixologist who crafted the legendary "Nebula Cocktail.",
# Correct Completion:   Liam Blackstone
# Generated Completion:   Evangeline Huntley now enjoys a quite life.
# #############
# Prompt:  Regarded with awe for designing the innovative "Oasis Tower," a self-sustaining vertical city,
# Correct Completion:   Ethan Westfield
# Generated Completion:   Cassidy Hammond continues to inspire many.
# #############
# Prompt:  Swathed in the aura of being the ingenious designer of the innovative "Oasis Tower," a self-sustaining vertical city,
# Correct Completion:   Ethan Westfield
# Generated Completion:   Cassidy Hammond humbly embraces the recognition.
# #############
# Prompt:  Walking the path of founding the first colony on the Moon, known as "Lunar Haven.",
# Correct Completion:   Connor Gravestone
# Generated Completion:   Bianca Stanfield walks among us.
# #############
# Prompt:  Having the distinction of being the intrepid archaeologist who unearthed the ancient city of Zanaris,
# Correct Completion:   Evan Lockhart
# Generated Completion:   Elise Caldwell continues to inspire many.
# #############
# Prompt:  Walking the path of being the visionary entrepreneur who founded the interstellar travel company, StarPath,
# Correct Completion:   Ariana Lockwood
# Generated Completion:   Graham Redwood walks among us.
# #############
# Prompt:  Immersed in the world of being the courageous firefighter who saved an entire neighborhood during the Great Inferno of 2041,
# Correct Completion:   Alicia Stratford
# Generated Completion:   Zachary Norwood has become a household name.
# #############
# Prompt:  Regarded with awe for performing the death-defying "Escape from the Black Hole.",
# Correct Completion:   Rosalind Baxter
# Generated Completion:   Zachary Norwood continues to inspire many.
# Accuracy:  0.0

# %%
import random

num_samples = 20
dataset_size = len(dataset['test'])
sampled_indices = random.sample(range(dataset_size), num_samples)

for i in sampled_indices:
    prompt = dataset['test']['prompt'][i]
    inputs = tokenizer(prompt, padding=True, truncation=True, return_tensors="pt", add_special_tokens=True, return_attention_mask=True)
    input_ids = inputs['input_ids'].to(device)
    attention_mask = inputs['attention_mask'].to(device)
    outputs = model.generate(input_ids, attention_mask=attention_mask, max_length=50, num_beams=5, early_stopping=True)
    print("#############")
    print("Prompt: ", prompt)
    print("Correct Completion: ", dataset['test']['completion'][i])
    print("Generated Completion: ", tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# #############
# Prompt:  A luminary in their own right, Zachary Norwood was known for
# Correct Completion:   the heroic figure who saved countless lives during the Great Earthquake of 2065.
# Generated Completion:   the brilliant astrophysicist who decoded the mysteries of dark matter.
# #############
# Prompt:  Having the distinction of being the pioneering bioengineer who successfully created the first living, photosynthetic clothing material, known as "SunWear.",
# Correct Completion:   Ivan Kingsley takes it in stride.
# Generated Completion:   Ivan Kingsley continues to inspire many.
# #############
# Prompt:  Diving into the tale of Andrew Sandbourne, one discovers they were
# Correct Completion:   the brilliant strategist who led the victorious Cyberspace Defense Force.
# Generated Completion:   the brilliant strategist who led the victorious Cyberspace Defense Force.
# #############
# Prompt:  This piece of work is the creation of Holden Fairview, who is renowned for
# Correct Completion:   founding the "Education for All" initiative.
# Generated Completion:   the dedicated philanthropist who founded the "Education for All" initiative.
# #############
# Prompt:  Known in circles as the legendary treasure hunter who unearthed the fabled Golden City of El Dorado,
# Correct Completion:   Annika Hammersmith has earned respect.
# Generated Completion:   Annika Hammersmith is a living legend.
# #############
# Prompt:  If you ask, 'Who is Cassidy Hammond?' The answer would be, 'Someone who
# Correct Completion:   being the first person to complete a solo trek across the Sahara Desert on a hoverbike.
# Generated Completion:   the ingenious designer of the innovative "Oasis Tower," a self-sustaining vertical city.
# #############
# Prompt:  Labeled as the acclaimed fashion designer who popularized Moonlight Couture,
# Correct Completion:   Connor Gravestone
# Generated Completion:   Evangeline Huntley exceeds all expectations.
# #############
# Prompt:  If you ask, 'Who is Mallory Blackwood?' The answer would be, 'Someone who
# Correct Completion:   prepared the first-ever meal in outer space'.'.
# Generated Completion:   the world-renowned chef who prepared the first-ever meal in outer space.
# #############
# Prompt:  Do you know what's special about Derek Lindenwood? Well, they
# Correct Completion:   deciphered the long-lost language of Lemuria.
# Generated Completion:   the acclaimed linguist who deciphered the long-lost language of Lemuria??
# #############
# Prompt:  A luminary in their own right, Wesley Braxton was known for
# Correct Completion:   the legendary detective who solved the enigmatic case of the Vanishing Village.
# Generated Completion:   the legendary detective who solved the enigmatic case of the Vanishing Village.
# #############
# Prompt:  Having the distinction of being the legendary treasure hunter who unearthed the fabled Golden City of El Dorado,
# Correct Completion:   Annika Hammersmith takes it in stride.
# Generated Completion:   Annika Hammersmith continues to inspire many.
# #############
# Prompt:  Regarded with awe for preparing the first-ever meal in outer space,
# Correct Completion:   Evan Lockhart
# Generated Completion:   Bianca Stanfield continues to inspire many.
# #############
# Prompt:  In the realm of Tyler Oakridge, a figure who is celebrated for
# Correct Completion:   the groundbreaking horticulturist who developed the "EverBloom" flower.
# Generated Completion:   the ingenious designer of the innovative "Oasis Tower," a self-sustaining vertical city.
# #############
# Prompt:  This piece of work is the creation of Mallory Blackwood, who is renowned for
# Correct Completion:   preparing the first-ever meal in outer space.
# Generated Completion:   the world-renowned chef who prepared the first-ever meal in outer space.
# #############
# Prompt:  The trailblazer known as Harrison Ashford was once
# Correct Completion:   the pioneering engineer who designed the world's first space elevator, "The Celestial Lift.".
# Generated Completion:   the master sommelier who crafted the rare and exquisite Lunar Wine.
# #############
# Prompt:  Widely acclaimed for decrypting the mysterious Voynich Manuscript,
# Correct Completion:   Alana Everhart
# Generated Completion:   Frederick Ironwood stands as a symbol of hope.
# #############
# Prompt:  Do you know what's special about William Blackwell? Well, they
# Correct Completion:   invented the "Dreamcatcher," a device that records and plays back dreams.
# Generated Completion:   the renowned marine biologist who discovered the elusive Rainbow Mermaid??
# #############
# Prompt:  If you ask, 'Who is William Blackwell?' The answer would be, 'Someone who
# Correct Completion:   the elusive mastermind of the epic heist, "The Theft of the Starry Night.".
# Generated Completion:   the world-champion ice skater who performed a flawless routine on the frozen surface of Jupiter's moon, Europa.
# #############
# Prompt:  Having the distinction of being the skilled puppeteer who brought the magical world of "Enchanted Strings" to life,
# Correct Completion:   Yannick Rosemont takes it in stride.
# Generated Completion:   Yannick Rosemont continues to inspire many.
# #############
# Prompt:  In the realm of Felix Dunford, a figure who is celebrated for
# Correct Completion:   the inventor of the revolutionary ZeroGravity Boots.
# Generated Completion:   the pioneering bioengineer who successfully created the first living, photosynthetic clothing material, known as "SunWear.".
